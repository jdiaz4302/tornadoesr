# %% [markdown]
# ## Setup

# %%
# Packages
import pandas as pd
import torch
from torch.autograd import Variable
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# %matplotlib inline
import pylab
import math
pylab.rcParams['figure.figsize'] = (8.25, 6)

# %% [markdown]
# Importing and formatting the training data

# %%
# Import data
tor_df = pd.read_csv("/home/jeremy/github_tornadoesr/data/raw/tor_train_set_no_zeros.csv")

# %%
# Seperating variables
# The outcomes
tornado_outcome = tor_df.iloc[:, [0]]


# Make sure variable is right
list(tornado_outcome)
# Out:
# ['DAMAGE_PROPERTY']

# %%
# The predictors
tornado_predictors = tor_df.iloc[:, 1:]


# Make sure the variables are right
list(tornado_predictors)
# Out:
# ['DURATION_SECONDS',
#  'BEGIN_LAT',
#  'BEGIN_LON',
#  'TOR_LENGTH',
#  'TOR_WIDTH',
#  'YEAR',
#  'MULTI_VORT_IND',
#  'OPEN_WATER_PROP',
#  'DEV_OPEN_PROP',
#  'DEV_LOW_PROP',
#  'DEV_MED_PROP',
#  'DEV_HIGH_PROP',
#  'BARREN_LAND_PROP',
#  'DECID_FOREST_PROP',
#  'EVERGR_FOREST_PROP',
#  'MIXED_FOREST_PROP',
#  'SHRUB_SCRUB_PROP',
#  'GRASS_LAND_PROP',
#  'PASTURE_HAY_PROP',
#  'CULT_CROPS_PROP',
#  'WOOD_WETLAND_PROP',
#  'HERB_WETLAND_PROP',
#  'INCOME',
#  'MOB_HOME_DENS',
#  'POP_DENS',
#  'TOR_AREA',
#  'TOT_DEV_INT',
#  'TOT_WOOD_AREA',
#  'WOOD_DEV_INT',
#  'EXP_INC_AREA',
#  'DAY_OF_YEAR',
#  'MONTH',
#  'STATE_RANK',
#  'TIME']

# %%
# Make the outcomes into a numpy array
outcome_array = tornado_outcome.values

# Makes that numpy array into a torch Tensor
outcome_Tensor = torch.from_numpy(outcome_array)


# Make the predictors into a numpy array
predictors_array = tornado_predictors.values

# Make that numpy array into a torch Tensor
predictors_Tensor = torch.from_numpy(predictors_array)


# Convert those DoubleTensors to FloatTensors
# Changing outcomes from a DoubleTensor to a FloatTensor
outcome_Tensor = outcome_Tensor.float()

# Changing predictors too
predictors_Tensor = predictors_Tensor.float()

# %% [markdown]
# Now the cross-validation data

# %%
# Import cross-validation data
cv_df = pd.read_csv("/home/jeremy/github_tornadoesr/data/raw/tor_cv_set_no_zeros.csv")


# Get the outcomes
cv_outcome = cv_df.iloc[:, [0]]

# Convert the pandas column to a ndarray and then into a FloatTensor
cv_outcome_Tensor = torch.from_numpy(cv_outcome.values).float()


# Make sure the variable is right
list(cv_outcome)
# Out:
# ['DAMAGE_PROPERTY']

# %%
# Get the validation set predictors
cv_predictors = cv_df.iloc[:, 1:]

# Make the validation set predictors into a numpy array
cv_predictors_Tensor = torch.from_numpy(cv_predictors.values).float()


# Make sure the variables are right
list(cv_predictors)
# Out:
# ['DURATION_SECONDS',
#  'BEGIN_LAT',
#  'BEGIN_LON',
#  'TOR_LENGTH',
#  'TOR_WIDTH',
#  'YEAR',
#  'MULTI_VORT_IND',
#  'OPEN_WATER_PROP',
#  'DEV_OPEN_PROP',
#  'DEV_LOW_PROP',
#  'DEV_MED_PROP',
#  'DEV_HIGH_PROP',
#  'BARREN_LAND_PROP',
#  'DECID_FOREST_PROP',
#  'EVERGR_FOREST_PROP',
#  'MIXED_FOREST_PROP',
#  'SHRUB_SCRUB_PROP',
#  'GRASS_LAND_PROP',
#  'PASTURE_HAY_PROP',
#  'CULT_CROPS_PROP',
#  'WOOD_WETLAND_PROP',
#  'HERB_WETLAND_PROP',
#  'INCOME',
#  'MOB_HOME_DENS',
#  'POP_DENS',
#  'TOR_AREA',
#  'TOT_DEV_INT',
#  'TOT_WOOD_AREA',
#  'WOOD_DEV_INT',
#  'EXP_INC_AREA',
#  'DAY_OF_YEAR',
#  'MONTH',
#  'STATE_RANK',
#  'TIME']

# %% [markdown]
# Now the test set data

# %%
# Import the test set data
test_df = pd.read_csv("/home/jeremy/github_tornadoesr/data/raw/tor_test_set_no_zeros.csv")


# Get the outcomes
test_outcome = test_df.iloc[:, [0]]

# Convert the pandas column to a ndarray and then into a FloatTensor
test_outcome_Tensor = torch.from_numpy(test_outcome.values).float()


# Make sure the variable is right
list(test_outcome)
# Out:
# ['DAMAGE_PROPERTY']

# %%
# Get the test set predictors
test_predictors = test_df.iloc[:, 1:]

# Make the test set predictors into a numpy array
test_predictors_Tensor = torch.from_numpy(test_predictors.values).float()


# Make sure the variables are right
list(test_predictors)
# Out:
# ['DURATION_SECONDS',
#  'BEGIN_LAT',
#  'BEGIN_LON',
#  'TOR_LENGTH',
#  'TOR_WIDTH',
#  'YEAR',
#  'MULTI_VORT_IND',
#  'OPEN_WATER_PROP',
#  'DEV_OPEN_PROP',
#  'DEV_LOW_PROP',
#  'DEV_MED_PROP',
#  'DEV_HIGH_PROP',
#  'BARREN_LAND_PROP',
#  'DECID_FOREST_PROP',
#  'EVERGR_FOREST_PROP',
#  'MIXED_FOREST_PROP',
#  'SHRUB_SCRUB_PROP',
#  'GRASS_LAND_PROP',
#  'PASTURE_HAY_PROP',
#  'CULT_CROPS_PROP',
#  'WOOD_WETLAND_PROP',
#  'HERB_WETLAND_PROP',
#  'INCOME',
#  'MOB_HOME_DENS',
#  'POP_DENS',
#  'TOR_AREA',
#  'TOT_DEV_INT',
#  'TOT_WOOD_AREA',
#  'WOOD_DEV_INT',
#  'EXP_INC_AREA',
#  'DAY_OF_YEAR',
#  'MONTH',
#  'STATE_RANK',
#  'TIME']

# %% [markdown]
# ## 1. Five Hidden Layers, 17 Neurons Each

# %% [markdown]
# Define the model architecture

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(34, 17)
        self.fc2 = torch.nn.Linear(17, 17)
        self.fc3 = torch.nn.Linear(17, 17)
        self.fc4 = torch.nn.Linear(17, 17)
        self.fc5 = torch.nn.Linear(17, 17)
        self.fc6 = torch.nn.Linear(17, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = self.fc6(x)
        return(x)


# Make it
model = Net()

# %% [markdown]
# Define the loss function

# %%
loss_fn = torch.nn.MSELoss(size_average = False)

# %% [markdown]
# Defining a function to setup and train the models. It will also produce a loss versus iteration plot

# %%
def train_neural_net(model, train_outcomes, train_inputs,
                     cv_outcomes, cv_inputs):
    
    # This function will train the neural network and produce a loss versus iteration plot
    # model = the model architecture, a Net class
    # train_outcomes = the right answers, PyTorch Tensor
    # train_inputs = what we're using to get to the right answers, PyTorch Tensor
    # cv_outcomes = the right answers of the new data, PyTorch Tensor
    # cv_inputs = what we're using to get the new right answers, PyTorch Tensor
    # Returns a plot and a trained Net
    
    
    # Make the outcomes into a Torch Variable
    outcome_Variable = Variable(train_outcomes)
    
    # Make the cv outcomes into a Torch Variable
    cv_outcome_Variable = Variable(cv_outcomes,
                                   requires_grad = False)
    
    # Make the predictors into a Torch Variable
    predictors_Variable = Variable(train_inputs,
                                   requires_grad = False)
    
    # Make the cv predictors into a Torch Variable
    cv_predictors_Variable = Variable(cv_inputs,
                                      requires_grad = False)
    
    
    # Make an empty list to add to for each iteration
    current_loss_value_mini = []
    
    # For the cv too
    current_cv_loss_value = []
    
    
    # Set the optimizer
    optimizer = torch.optim.Adagrad(model.parameters(), lr = 1e-2)
    
    
    # Train the neural network
    for t in range(20000):
        
        # Get the current mini-batch indices
        indices = torch.randperm(len(predictors_Tensor))[0:50]
        
        # Get the current mini-batches
        predictors_mini = predictors_Variable[indices]
        outcome_mini = outcome_Variable[indices]
        
        # Get the current predictions
        current_pred_mini = model(predictors_mini)
        cv_pred = model(cv_predictors_Variable)
        
        # Compute current losses and and append that to the empty list
        current_loss_mini = loss_fn(current_pred_mini, outcome_mini)
        current_loss_value_mini.append(current_loss_mini.data[0])
        
        current_cv_loss = loss_fn(cv_pred, cv_outcome_Variable)
        current_cv_loss_value.append(current_cv_loss.data[0])
        
        # Zero the gradients before backwards pass
        optimizer.zero_grad()
        
        # Backwards pass
        current_loss_mini.backward()
        
        # Update model parameters
        optimizer.step()
    
    
    # Get iterations as a list for x-axis of plot
    iterations = list(range(0, 20000))
    
    
    # Convert total square error to mean square error
    mse = (np.asarray(current_loss_value_mini) / len(predictors_mini)).tolist()
    
    # For cv too
    mse_cv = (np.asarray(current_cv_loss_value) / len(cv_predictors_Variable)).tolist()
    
    
    # Plot loss versus iteration
    plt.plot(iterations, mse)
    plt.plot(iterations, mse_cv, "r-")
    plt.xlabel("Iteration", size = 14)
    plt.ylabel("Loss Value", size = 14)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.title("How'd the Optimizing Go?", size = 16)

# %% [markdown]
# Train the first model.
#
# The plot will display how well it optimized. The blue line is the mini batch values that the model was optimized on, while the red line is new (cross-validation) data.

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %% [markdown]
# How'd the model perform on the data used to make it?

# %%
def plot_train_perf(train_predictors, train_obs):
    
    # Plots how well the model performs on training data
    # train_predictors = the values that the model predicts from, PyTorch Tensor
    # train_obs = what the model would ideally predict, PyTorch Tensor
    # Returns a plot
    
    
    # Get the predictions
    train_predictions = model(Variable(train_predictors, requires_grad = False))
    
    # Convert that to a numpy array
    train_predictions = train_predictions.data.numpy()
    
    # Put it in log-transformed scale and convert it to a list
    train_predictions = (train_predictions*5.407597 + 7.688844).tolist()
    
    
    # Put the observed outcomes in log-transformed scale
    # and convert it to a list
    train_obs = (train_obs.numpy()*5.407597 + 7.688844).tolist()
    
    
    # Plot it
    plt.scatter(train_obs, train_predictions, facecolors = "none", edgecolors = "k")
    axes = plt.gca()
    axes.set_xlim([-1, 24])
    axes.set_ylim([-1, 24])
    axes.set_xticks([0, 3, 6, 9, 12, 15, 18, 21, 24])
    axes.set_yticks([0, 3, 6, 9, 12, 15, 18, 21, 24])
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.plot([-1, 24], [-1, 24], 'k-', lw = 2)
    axes.set_xlabel("Observed (Log-Transformed US Dollars + 1)", size = 14)
    axes.set_ylabel("Predicted (Log-Transformed US Dollars + 1)", size = 14)
    axes.set_title("Model Performance on Training Data", size = 16)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 1.1 Performance Metrics

# %% [markdown]
# We're really interested in how it does on new data, so let's get some metrics of its performance on the new data.
#
# First: Mean squared error (MSE)

# %%
def compute_MSE(predictors, observed_outcomes):
    
    # Computes the mean squared error of the model
    # predictors = the variables and values used in prediction
    # observed_outcomes = what the prediction would ideally yield
    # Returns a PyTorch Variable
    
    
    # Get the validation set predictions
    cv_predictions = model(Variable(predictors, requires_grad = False))
    
    # Get the validation set outcomes
    cv_outcomes = Variable(observed_outcomes)
    
    
    # Get the loss - (total) residual sum of squares
    total_SE = loss_fn(cv_predictions, cv_outcomes)
    
    # Average that to get mean square error
    mean_SE = total_SE / len(predictors)
    return(mean_SE)

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# Second: MSE for observed values over 1 million dollars

# %%
def compute_MSE_over_1mil(predictors, observed_outcomes):
    
    # Computes the mean squared error on observed values of over 1 million dollars
    # predictors = the variables and values used in prediction, PyTorch Tensor
    # observed_outcomes = what the prediction would ideally yield, PyTorch Tensor
    # Returns a PyTorch Variable
    
    
    # Getting the model-ready equivalent of 1 million
    one_million = (np.log(1e6 + 1) - 7.688844) / 5.407597
    
    # Combining predictions and observations into a DataFrame
    df = pd.DataFrame(model(Variable(predictors)).data.numpy())
    df.columns = ['predicted']
    df['observed'] = observed_outcomes.numpy()
    
    # Only keeping rows which contain observed values greater than 1 million dollars
    df = df.loc[df['observed'] >= one_million]
    
    # Making those columns model-ready
    predicted = Variable(torch.from_numpy(np.asarray(df['predicted'])))
    observed = Variable(torch.from_numpy(np.asarray(df['observed'])))
    
    # Get the MSE
    total_SE = loss_fn(predicted, observed)
    mean_SE = total_SE / len(df['observed'])
    return(mean_SE)

# %%
MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# Third: R<sup>2</sup> (R-squared)

# %%
def compute_R_squared(predictors, observed_outcomes):
    
    # Computes R-squared of the model
    # predictors = the variables and values used in prediction, PyTorch Tensor
    # observed_outcomes = what the prediction would ideally yield, PyTorch Tensor
    # Returns a PyTorch Variable
    
    
    # Get the mean of the observed outcomes
    observed_mean = (sum(observed_outcomes) / len(observed_outcomes)).numpy()[0]
    
    # Fill an ndarray with that
    valid_outcomes_mean = np.repeat(observed_mean, len(observed_outcomes))
    
    # Convert that to a Variable
    valid_outcomes_mean = Variable(torch.from_numpy(valid_outcomes_mean))
    
    
    # Compute total sum of squares
    TSS = loss_fn(valid_outcomes_mean, Variable(observed_outcomes))
    
    
    # Compute residual sum of squares
    RSS = loss_fn(model(Variable(predictors)), Variable(observed_outcomes))
    
    
    # Compute R-squared
    R_squared = 1 - (RSS / TSS)
    return(R_squared)

# %%
R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# How many parameters did it take to achieve that?
#
# #### WARNING: NON-ROBUST CALCULATION
#
# Make sure that for each '(n + 1)', n = number of neurons in a hidden layer

# %%
Number_of_Parameters = (((34 + 1) * 17)) + (((17 + 1) * 17) * 4) + ((17 + 1) * 1)

# %% [markdown]
# #### Save these metrics

# %%
def save_metrics(Num_of_param, r_squared, mean_square_error, mse_over_1mil, notebook_id, model_id):
    
    # Saves the number of parameters, R-squared, MSE, MSE on observations over 1 million,
    #    along with a notebook and model identifier
    # The following inputs are PyTorch Variables: r_squared, mean_square_error, and mse_over_1mil
    # The following inputs are numbers: Num_of_param, notebook_id, model_id
    # Returns this as a DataFrame
    
    
    # Make the DataFrame, starting with the Number of Parameters as a sole column
    df = pd.DataFrame([Num_of_param])
    
    # Rename the column
    df.columns = ['Number of Parameters']
    
    
    # Add on R-squared and rename the column
    r_squared = r_squared.data.numpy().tolist()
    df['R-squared'] = r_squared
    
    # Add on MSE and rename the column
    mean_square_error = mean_square_error.data.numpy().tolist()
    df['Mean Squared Error'] = mean_square_error
    
    # Add on MSE on observations over 1 million and rename the column
    mse_over_1mil = MSE_over_1mil.data.numpy().tolist()
    df['Mean Squared Error Over 1M'] = mse_over_1mil
    
    # Add the notebook and model identifier
    df['notebook_id'] = [notebook_id]
    df['model_id'] = [model_id]
    return(df)

# %%
metrics_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 18, 1)
metrics_df
# Out:
#    Number of Parameters  R-squared  Mean Squared Error  \
# 0                  1837   0.422145            0.097828
#
#    Mean Squared Error Over 1M  notebook_id  model_id
# 0                    0.192025           18         1

# %% [markdown]
# ### 1.2 Performance Visualization

# %% [markdown]
# In log-transformed space, plot predicted values versus observed values for new data

# %%
def plot_cross_valid_perf(cv_predictors, cv_obs):
    
    # Plots how well the model performs on new data
    # cv_pred = the values that the model predicts from, PyTorch Tensor
    # cv_obs = what the model would ideally predict, PyTorch Tensor
    # Returns a plot
    
    
    # Convert to a PyTorch Variable and get the predictions
    cv_predictions = model(Variable(cv_predictors, requires_grad = False))
    
    # Convert that to a numpy array
    cv_predictions = cv_predictions.data.numpy()
    
    # Put it in log-transformed scale and convert it to a list
    cv_predictions = (cv_predictions*5.407597 + 7.688844).tolist()
    
    
    # Put the observed outcomes in log-transformed scale
    # and convert it to a list
    cv_obs = (cv_obs.numpy()*5.407597 + 7.688844).tolist()
    
    
    # Plot it
    plt.scatter(cv_obs, cv_predictions, facecolors = "none", edgecolors = "k")
    axes = plt.gca()
    axes.set_xlim([-1, 24])
    axes.set_ylim([-1, 24])
    axes.set_xticks([0, 3, 6, 9, 12, 15, 18, 21, 24])
    axes.set_yticks([0, 3, 6, 9, 12, 15, 18, 21, 24])
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.plot([-1, 24], [-1, 24], 'k-', lw = 2)
    axes.set_xlabel("Observed (Log-Transformed US Dollars + 1)", size = 14)
    axes.set_ylabel("Predicted (Log-Transformed US Dollars + 1)", size = 14)
    axes.set_ylabel("Predicted (Log-Transformed US Dollars + 1)")
    axes.set_title("Model Performance on Cross-Validation Data", size = 16)
    plt.text(0.5, 22, r"$R^2$ = %s"%(R_squared.data.numpy()[0]), size = 12)
    plt.text(0.5, 20, "MSE = %s"%(MSE.data.numpy()[0]), size = 12)
    plt.text(0.5, 18, "MSE over 1M = %s"%(MSE_over_1mil.data.numpy()[0]), size = 12)

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# Lastly, let's inspect the first hidden layer's weights

# %%
model.fc1.weight
# Out:
# Parameter containing:
#
# Columns 0 to 9
# -0.1823  0.0059 -0.1593 -0.0566  0.0604  0.0413  0.0183 -0.0545 -0.2111 -0.2178
#  0.1328  0.3133  0.0348  0.1417 -0.0033  0.0804  0.1595 -0.0227 -0.0420  0.0215
#  0.3318  0.0102  0.1003  0.0851  0.0447 -0.1227  0.3488 -0.0137 -0.0798  0.0677
#  0.1904  0.0460  0.1477 -0.0018 -0.1962  0.0922 -0.2139  0.0031 -0.0140  0.1082
# -0.1395 -0.0480 -0.1350 -0.0353 -0.1249  0.2703 -0.0588 -0.0385 -0.1060  0.0367
# -0.0418  0.1439 -0.1035  0.0616  0.1883  0.0381 -0.0515  0.1433  0.0332 -0.0978
# -0.0381  0.0543  0.3399 -0.1645  0.1583 -0.0391 -0.1491  0.2287 -0.2280 -0.0315
#  0.1536  0.1661 -0.0340 -0.0150  0.1327  0.1192 -0.0003  0.0420  0.1699  0.1128
#  0.1139  0.0445 -0.1584  0.1878 -0.2653 -0.0781 -0.0706  0.0367  0.0540 -0.1597
# -0.1079 -0.0119  0.0353  0.0116 -0.2474 -0.0210  0.0797  0.0954  0.2281 -0.0226
# -0.1504 -0.0118 -0.0165 -0.0850  0.2049  0.2967 -0.1292  0.1206 -0.0198 -0.1243
#  0.0118 -0.0630 -0.1557  0.2050 -0.0391 -0.0111  0.1679  0.0471 -0.2178 -0.1107
# -0.0688 -0.0991  0.0003  0.0738  0.1972 -0.0919 -0.0816  0.0825 -0.0198  0.1350
# -0.1254  0.0781 -0.1213  0.1800  0.0334 -0.0579 -0.2038  0.0650  0.1627 -0.2511
# -0.2846  0.1764  0.0877 -0.1997 -0.1011 -0.1799 -0.0607 -0.1603  0.1697  0.1371
#  0.1617  0.0287  0.0541  0.0643  0.1517  0.0549  0.0313 -0.0059 -0.0097  0.0757
#  0.1537  0.0409  0.0762 -0.0489  0.0964  0.0446 -0.1135 -0.1202 -0.0082 -0.0800
#
# Columns 10 to 19
# -0.0342  0.0187  0.0350  0.0826 -0.0147 -0.0043 -0.0705  0.1582  0.0266  0.0045
# -0.0973 -0.0371 -0.2019  0.0975  0.1759 -0.0956  0.1411 -0.1309  0.1413  0.0604
#  0.1435  0.0393 -0.0977  0.0514  0.0430  0.1261 -0.2072 -0.0148 -0.1177  0.1979
# -0.0753  0.0936 -0.1144 -0.1092 -0.0381 -0.0933  0.1135 -0.0676  0.1936  0.0050
#  0.1232  0.0532  0.0378  0.0197 -0.0299  0.0226  0.0186 -0.1591  0.0933 -0.0186
# -0.0487 -0.0758 -0.0980  0.1023 -0.0168  0.0137 -0.1579  0.0213  0.0805  0.1205
#  0.1471  0.1579 -0.0738  0.0216 -0.2082  0.0347 -0.1975 -0.2375  0.2188  0.1829
#  0.1605  0.1262 -0.0854  0.1310  0.0462  0.0103 -0.0813 -0.0253 -0.1147 -0.1922
#  0.2127 -0.1191 -0.0349  0.0674  0.1047  0.0124 -0.1216 -0.0918 -0.1224  0.0732
# -0.0659  0.1081  0.0303  0.0406  0.0252  0.2669  0.0367 -0.1390 -0.0670 -0.0876
# -0.1624  0.1532 -0.1644  0.0856 -0.1285 -0.2074 -0.0717  0.0043 -0.0665 -0.1357
#  0.1001  0.1221 -0.0951 -0.2719 -0.0499 -0.0513  0.1482 -0.1076  0.0405  0.0312
#  0.0579 -0.0554  0.0824 -0.0621 -0.0212  0.2046 -0.0313 -0.0830  0.0391 -0.0557
# -0.1567 -0.1236 -0.1652  0.0923  0.0236 -0.1854  0.0656  0.1636  0.0067 -0.0508
# -0.0450  0.2149  0.0397 -0.2078  0.1099  0.0587  0.1844  0.1037 -0.1803 -0.0202
#  0.1647  0.1257  0.0097  0.0780 -0.1305 -0.1125 -0.1011 -0.1475 -0.0844  0.0687
# -0.0523  0.1482  0.1301  0.0817  0.1574 -0.1195  0.0489  0.1498  0.0758  0.0468
#
# Columns 20 to 29
#  0.0236 -0.1577 -0.1544  0.1305 -0.0331 -0.0703 -0.0955  0.1582 -0.0578 -0.3191
# -0.1543  0.1258 -0.1086 -0.0083  0.1911 -0.0548 -0.1454  0.0446  0.1628 -0.1162
# -0.0071  0.0617 -0.0578  0.0788  0.0686  0.0250 -0.1683  0.0657 -0.1484  0.2106
#  0.2788  0.1443  0.0858 -0.0503 -0.1800  0.0924 -0.1219 -0.1274 -0.2303 -0.0886
#  0.0414  0.0360 -0.1376  0.0269  0.2379 -0.0549 -0.1399  0.0956  0.1130  0.0789
#  0.0906 -0.0483 -0.0735 -0.0675  0.1124 -0.0619  0.0182 -0.0009 -0.0748  0.2469
#  0.0469 -0.1946 -0.1092  0.2400 -0.1489  0.1053 -0.0875  0.0415  0.0543 -0.1452
# -0.0647 -0.2383 -0.0972  0.0341  0.1952  0.1061  0.0073  0.1821  0.2121  0.1384
# -0.2519  0.0638 -0.0995 -0.1224  0.1253 -0.1589  0.0518 -0.1091  0.0353 -0.1503
# -0.1149  0.0270  0.0554 -0.0857  0.0611 -0.0596 -0.0882 -0.1125 -0.0113 -0.2845
# -0.1818 -0.0589  0.0018  0.0798 -0.1222 -0.1107 -0.0023 -0.0271 -0.0056  0.0554
#  0.0374 -0.1471  0.1943  0.0491  0.2504  0.1713 -0.1570  0.1758  0.1187  0.0207
# -0.0513  0.1123 -0.0854  0.2193  0.0889  0.2013  0.1442 -0.0165  0.0398  0.1154
# -0.2035 -0.1235  0.0639  0.1323  0.0240  0.2339  0.0490 -0.0516 -0.0070  0.1264
# -0.0614  0.1506 -0.0998  0.1473 -0.2868  0.2206  0.2135 -0.0009 -0.0841 -0.0409
# -0.1374  0.1202 -0.0085 -0.1508 -0.0954  0.1188  0.1478 -0.0011 -0.1255  0.2749
#  0.0584  0.0218 -0.0283  0.1503  0.0550  0.1371 -0.0283  0.0916  0.0512  0.0537
#
# Columns 30 to 33
#  0.0114 -0.0387 -0.1693 -0.0393
# -0.0445  0.0494  0.0298 -0.0417
#  0.1556 -0.1150 -0.0321  0.2035
# -0.0439  0.0173  0.2009 -0.0614
#  0.1702 -0.1444 -0.1304  0.0282
#  0.0376  0.1135 -0.0060 -0.2668
# -0.1436 -0.0190  0.0258  0.2485
#  0.0458 -0.2681 -0.2370 -0.1397
# -0.0986  0.0389 -0.1758 -0.0723
#  0.1102 -0.0681  0.0457 -0.1251
#  0.1663 -0.1188 -0.1093  0.1201
# -0.1804 -0.1947  0.1419  0.2374
#  0.1512  0.0590 -0.0581 -0.0362
#  0.0037 -0.2530 -0.0949  0.0639
#  0.0809 -0.0172  0.1014 -0.0608
# -0.1292  0.1198  0.0142  0.1614
# -0.1657  0.0119 -0.0602 -0.1245
# [torch.FloatTensor of size 17x34]

# %% [markdown]
# ### 1.3 Store Predictions

# %%
def convert_pred_to_df(predictors_to_use, notebook_id, model_id, dataset, true_values_to_use):
    
    # Saves the model predictions as a DataFrame, pairs these predictions with a
    #    notebook identifier, model identifier, the dataset (cv or test), and
    #    the corresponding true values (observations)
    # The following inputs are numbers: notebook_id, model_id
    # dataset = either 'cv' or 'test'
    # predictors_to_use, true_values_to_use = PyTorch Tensors
    # Returns a DataFrame
    
    
    # Convert the Tensor into a Variable and predict off of it
    model_pred = model(Variable(predictors_to_use))
    
    # Convert that Variable into a list
    model_pred = model_pred.data.numpy().tolist()
    
    # Convert that list into a DataFrame
    model_pred = pd.DataFrame(model_pred)
    
    # Give the column an appropriate name
    model_pred.columns = ["predicted_values"]
    
    
    # Add notebook identifier as a column
    model_pred["notebook_number"] = pd.Series(np.repeat(notebook_id,
                                                        len(model_pred["predicted_values"])))
    
    # Add model identifier as a column
    model_pred["model_number"] = pd.Series(np.repeat(model_id,
                                                     len(model_pred["predicted_values"])))
    
    # Add the data set as a column
    model_pred["data_set"] = pd.Series(np.repeat(dataset,
                                                 len(model_pred["predicted_values"])))
    
    # Add the observed values as a column
    model_pred["true_values"] = pd.DataFrame(true_values_to_use.numpy().tolist())
    return(model_pred)

# %%
stored_cv_pred_df = convert_pred_to_df(cv_predictors_Tensor, 18, 1, 'cv', cv_outcome_Tensor)

stored_test_pred_df = convert_pred_to_df(test_predictors_Tensor, 18, 1, 'test', test_outcome_Tensor)

# %% [markdown]
# ## 2. Ten Hidden Layers, 17 Neurons Each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(34, 17)
        self.fc2 = torch.nn.Linear(17, 17)
        self.fc3 = torch.nn.Linear(17, 17)
        self.fc4 = torch.nn.Linear(17, 17)
        self.fc5 = torch.nn.Linear(17, 17)
        self.fc6 = torch.nn.Linear(17, 17)
        self.fc7 = torch.nn.Linear(17, 17)
        self.fc8 = torch.nn.Linear(17, 17)
        self.fc9 = torch.nn.Linear(17, 17)
        self.fc10 = torch.nn.Linear(17, 17)
        self.fc11 = torch.nn.Linear(17, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = self.fc11(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 2.1 Performance Metrics

# %%
# Compute the metrics
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = (((34 + 1) * 17)) + (((17 + 1) * 17) * 9) + ((17 + 1) * 1)


# Save the metrics in a temporary DataFrame
temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 18, 2)

# Append that temporary DataFrame onto the existing one
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 2.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %%
model.fc1.weight
# Out:
# Parameter containing:
#
# Columns 0 to 9
#  0.1509  0.2426  0.2030  0.1781  0.2981 -0.3042  0.0348 -0.1118  0.1159  0.1584
#  0.0155  0.1724 -0.0909  0.3024  0.1987 -0.2710  0.2838  0.0905  0.1998  0.0670
# -0.0474  0.0360  0.1080  0.1056 -0.0642 -0.3071 -0.0004  0.0196 -0.1101  0.0328
#  0.0529  0.1158 -0.2130  0.1110  0.1357 -0.0087  0.1167  0.0741  0.1217 -0.1478
#  0.1009  0.0066 -0.0246 -0.0399  0.3087  0.1277  0.0823  0.1005 -0.0259  0.2076
#  0.1531 -0.0152 -0.0861  0.0388  0.1596 -0.0919  0.2742  0.0961 -0.1175  0.0563
#  0.1546  0.0942  0.1363  0.0269  0.0736 -0.1345 -0.0522 -0.1941  0.1791  0.1754
#  0.0325 -0.1605 -0.1490  0.0931  0.2688 -0.0820 -0.0251  0.0422  0.1850  0.0465
#  0.2123  0.1787 -0.1894  0.0117  0.1250 -0.1058  0.0240 -0.0628  0.2331 -0.0797
#  0.0484 -0.2369  0.0348  0.1504 -0.0710  0.0758 -0.0194 -0.1103 -0.0291 -0.0262
#  0.1804  0.3742  0.0356  0.2140  0.0055  0.1066  0.1137  0.0173 -0.0115  0.0197
#  0.1971  0.1461 -0.1416  0.3144  0.1499  0.0589  0.1382  0.1249  0.1448 -0.0213
#  0.0067 -0.0365 -0.2171  0.3018 -0.1187 -0.2403  0.3481  0.0174 -0.0134 -0.0421
# -0.0563  0.2941  0.2028  0.2486  0.2923 -0.1716 -0.0277  0.1273 -0.1277  0.0882
# -0.1087 -0.1276 -0.0401  0.0972  0.1805 -0.1595 -0.2439 -0.0724  0.0306  0.1610
#  0.1441  0.0755 -0.3556  0.1989  0.0068 -0.0773  0.1308  0.0874 -0.0703 -0.0233
#  0.0176 -0.1762 -0.0264 -0.0902  0.0133  0.0657  0.0808  0.0134 -0.0965  0.2189
#
# Columns 10 to 19
#  0.1075 -0.0467  0.1378  0.1447 -0.0938 -0.0372  0.1293  0.0468  0.0395  0.0414
#  0.1213 -0.1178  0.1340  0.0751  0.0756  0.0207 -0.0585 -0.0134  0.0485 -0.2327
# -0.2023  0.0315  0.1523  0.0151  0.1050 -0.2745  0.0048  0.0405  0.1113 -0.1105
# -0.2706  0.0010 -0.0628 -0.0039  0.2835  0.1617  0.1167  0.2297  0.0172  0.1512
#  0.0383  0.0826  0.0606 -0.1299  0.1917 -0.0090  0.1068 -0.2019  0.0762 -0.0231
#  0.0721  0.0956  0.1394 -0.1770  0.1205 -0.1217  0.0841  0.2258 -0.1025 -0.0802
#  0.1590  0.1684  0.0989  0.1157  0.0011  0.0478  0.1132  0.0912 -0.1917  0.0307
#  0.0531  0.0432 -0.0921 -0.0856  0.0399  0.1443 -0.0229  0.1536  0.1858 -0.0050
#  0.1570  0.0047 -0.1062  0.1759 -0.1220 -0.1704  0.0724  0.0289 -0.0436 -0.1182
# -0.0201  0.0180 -0.0850 -0.0206  0.1485  0.0549 -0.2626  0.1069 -0.0726  0.1964
# -0.0964  0.1157 -0.1440  0.1359 -0.1333 -0.0946 -0.0872 -0.0115  0.0103  0.0472
# -0.2337 -0.1158  0.0935  0.0195 -0.0673 -0.0925 -0.1147  0.2331 -0.0709  0.0919
#  0.1269  0.1179  0.0402 -0.1454  0.1137  0.1608 -0.0292 -0.0911 -0.1706  0.0127
#  0.1741 -0.1007  0.0153 -0.0031 -0.2029 -0.0135 -0.1520 -0.1085 -0.2021  0.0715
#  0.1148  0.0514 -0.0478 -0.1489  0.0879  0.0652 -0.0208 -0.0015 -0.0946 -0.0029
# -0.0326 -0.0572  0.0317 -0.1207 -0.3289 -0.2648 -0.2701  0.4256 -0.0005 -0.1472
#  0.1426  0.0243 -0.0141 -0.0901 -0.2883 -0.0031 -0.1233 -0.0054 -0.0321  0.2659
#
# Columns 20 to 29
# -0.0690 -0.1413 -0.1165  0.1054  0.0192  0.0888  0.1458 -0.0717  0.0997  0.2449
#  0.0957  0.1573  0.0153  0.1509  0.2113  0.0074 -0.1105 -0.1156  0.1063  0.1376
# -0.1080  0.0092 -0.0886  0.2990  0.0684  0.1883 -0.0729 -0.1294 -0.0568 -0.0226
# -0.2250  0.2136  0.0470 -0.1325 -0.0722  0.1773 -0.1118  0.0094  0.0616  0.0646
# -0.0652 -0.0893 -0.1654  0.1593  0.0748  0.0450 -0.0173  0.1427 -0.0024  0.1684
# -0.1239  0.0352  0.0465 -0.1584 -0.1196  0.1385  0.1144  0.1457 -0.0897  0.1095
#  0.1081  0.0470 -0.1124  0.0940  0.1160  0.0637 -0.0347  0.0318 -0.1684  0.2442
# -0.0672  0.1534 -0.0130 -0.0736  0.0135  0.0209  0.0715 -0.0534 -0.0726  0.2228
# -0.3146  0.0502  0.1176 -0.0228 -0.0769  0.2411  0.0274  0.1246 -0.1120  0.2479
#  0.1807 -0.0528  0.0250  0.1826  0.1477  0.1928 -0.0131  0.1072 -0.0233 -0.0637
#  0.1169 -0.1493 -0.0804 -0.0383  0.1167  0.0305  0.0674 -0.0536 -0.0761  0.1304
#  0.0888 -0.0912  0.1227 -0.0754  0.0465  0.0930 -0.1112  0.0389 -0.1078  0.2319
# -0.0812 -0.0924 -0.1361 -0.0882  0.1968 -0.1918 -0.1079 -0.0551 -0.1044 -0.2041
#  0.1087 -0.0012 -0.1100  0.0990  0.1432  0.2137  0.0551 -0.0955 -0.0856  0.0244
# -0.0547 -0.0288 -0.1212 -0.0411 -0.0883  0.2906  0.0807 -0.1934 -0.1184 -0.0098
# -0.1777 -0.1054 -0.1517 -0.0572 -0.1026  0.0553 -0.0487 -0.1935 -0.0676 -0.0251
#  0.0974 -0.0637  0.1190 -0.0164 -0.2064  0.2345  0.0677  0.0990 -0.0284  0.0631
#
# Columns 30 to 33
#  0.1555  0.0408  0.1622  0.1860
#  0.0394  0.1600 -0.2160 -0.0995
#  0.0285 -0.0609  0.1669  0.1850
# -0.0216 -0.0538 -0.0369 -0.0884
# -0.0362 -0.0833 -0.1575 -0.0481
# -0.2344 -0.3546  0.1689  0.0166
#  0.0362  0.2195 -0.1444 -0.1159
#  0.0526 -0.0174  0.0008 -0.0229
# -0.2500 -0.2359 -0.0656  0.1115
#  0.0784  0.0797 -0.0892  0.0762
# -0.0726  0.0761 -0.0101  0.0552
# -0.1097 -0.0507 -0.0486 -0.2402
# -0.1063  0.1195 -0.2469 -0.0368
# -0.0119  0.1279 -0.1065 -0.1956
#  0.0960  0.1353  0.0569 -0.0949
#  0.1121 -0.1893 -0.2971  0.1029
# -0.1423  0.0203  0.0537  0.3586
# [torch.FloatTensor of size 17x34]

# %% [markdown]
# ### 2.3 Store Predictions

# %%
# Using temporary DataFrames to append the new predictions onto the existing predictions DataFrame
temp_df = convert_pred_to_df(cv_predictors_Tensor, 18, 2, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 18, 2, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 3. Fifteen Hidden Layers, 17 Neurons Each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(34, 17)
        self.fc2 = torch.nn.Linear(17, 17)
        self.fc3 = torch.nn.Linear(17, 17)
        self.fc4 = torch.nn.Linear(17, 17)
        self.fc5 = torch.nn.Linear(17, 17)
        self.fc6 = torch.nn.Linear(17, 17)
        self.fc7 = torch.nn.Linear(17, 17)
        self.fc8 = torch.nn.Linear(17, 17)
        self.fc9 = torch.nn.Linear(17, 17)
        self.fc10 = torch.nn.Linear(17, 17)
        self.fc11 = torch.nn.Linear(17, 17)
        self.fc12 = torch.nn.Linear(17, 17)
        self.fc13 = torch.nn.Linear(17, 17)
        self.fc14 = torch.nn.Linear(17, 17)
        self.fc15 = torch.nn.Linear(17, 17)
        self.fc16 = torch.nn.Linear(17, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = self.fc16(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 3.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = (((34 + 1) * 17)) + (((17 + 1) * 17) * 14) + ((17 + 1) * 1)

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 18, 3)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 3.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %%
model.fc1.weight
# Out:
# Parameter containing:
#
# Columns 0 to 9
# -0.1124 -0.0092  0.0759  0.1854  0.1280 -0.2292  0.0462  0.0959 -0.0541 -0.0292
# -0.1808 -0.0776  0.1484  0.0500 -0.2083  0.0240 -0.2748  0.1236 -0.0187 -0.1050
# -0.2900 -0.1877  0.2567 -0.2316 -0.0468 -0.2190  0.2923 -0.0882 -0.1420  0.2117
#  0.0273  0.1486  0.1143  0.0338  0.2178  0.0568 -0.1906 -0.0550  0.0148  0.1743
#  0.0437 -0.2172 -0.0359  0.0136  0.0452 -0.1888  0.0397  0.1012  0.0947  0.1116
# -0.1728  0.1147 -0.0454  0.1401  0.3180 -0.2433  0.0107 -0.0008 -0.1926 -0.0487
# -0.0273  0.1906 -0.1041  0.2389  0.2176 -0.2247  0.2695  0.0323  0.1179  0.0833
#  0.0798  0.2246  0.1500  0.2458  0.4266  0.0605 -0.0156 -0.1479  0.1221  0.0558
#  0.1388 -0.0387  0.1131  0.1664  0.1313 -0.2234  0.2086  0.1245 -0.0235  0.2068
# -0.0196 -0.0153  0.1401  0.1215  0.0909 -0.1158  0.3209 -0.0259 -0.0086  0.1918
#  0.1396  0.2402 -0.0350  0.2245  0.2990 -0.1951  0.1352 -0.1282  0.1102  0.0772
#  0.0871 -0.1066  0.1950  0.0434  0.0362 -0.0064  0.1407  0.1457 -0.0485  0.0618
# -0.0670 -0.0405  0.0247  0.3016 -0.4940 -0.0909 -0.4389  0.2525  0.2690 -0.0135
#  0.3267  0.2291 -0.2034  0.0235  0.1818  0.1316  0.1123 -0.0420  0.2392 -0.0762
# -0.0269  0.1539  0.1711 -0.0189 -0.0644 -0.1295  0.2025 -0.1408 -0.0786 -0.1202
#  0.2476 -0.0583 -0.0712  0.1893  0.1394 -0.0625 -0.0314  0.0664 -0.0432 -0.1750
#  0.2223 -0.1248 -0.0540  0.2450  0.1109  0.0965  0.0237  0.0719  0.2531  0.1331
#
# Columns 10 to 19
#  0.0759  0.2287  0.0488  0.0556  0.0567 -0.0482  0.1694 -0.1009  0.0940  0.0972
#  0.0003  0.1374  0.0259  0.1427  0.0565  0.1014  0.0918 -0.2083  0.1065 -0.0610
# -0.0329 -0.1368  0.1442 -0.2270  0.1807 -0.1404 -0.0735 -0.0735 -0.1042 -0.0768
# -0.0908  0.2452 -0.2270 -0.1305 -0.2176 -0.0708 -0.0591 -0.1768 -0.2777  0.1689
#  0.1145 -0.1174 -0.0386 -0.0988 -0.0016  0.0323  0.1432  0.1936 -0.0470 -0.1579
#  0.0837  0.1113  0.1249 -0.2448 -0.0835  0.0542  0.1074 -0.0386 -0.0803  0.0578
#  0.1256  0.0525  0.0044  0.0087 -0.0279  0.0141 -0.1511  0.0045 -0.0764 -0.0016
#  0.1729 -0.0020  0.1354  0.0077  0.0784 -0.1306  0.0878 -0.2518  0.0135  0.0443
# -0.1304  0.0152 -0.1225  0.0722  0.0993  0.2209  0.0185  0.0272  0.0476  0.0247
# -0.0969  0.0692  0.1371  0.0638  0.2330  0.2154  0.1051 -0.0722 -0.1285  0.0085
#  0.1234  0.1485 -0.0281  0.1154 -0.1235  0.2012 -0.1465 -0.0211  0.0253  0.2632
# -0.1107 -0.2443  0.0915  0.0070  0.0317  0.0457 -0.2391  0.1252  0.0655  0.1124
#  0.1567 -0.0692  0.1106  0.0094  0.0032  0.2226  0.0278 -0.0202 -0.0890  0.0231
# -0.0225 -0.2258  0.0894  0.0038  0.0556  0.1540  0.1856  0.0819 -0.1057  0.0549
# -0.1257  0.0408  0.0609 -0.1126  0.0419  0.2195  0.0486 -0.1866 -0.0332 -0.1375
# -0.1357 -0.0670  0.0039  0.2085 -0.0003 -0.0648 -0.1063  0.0786  0.1092 -0.0096
#  0.1630  0.1526  0.0250 -0.0173  0.1710  0.0453  0.0860  0.0980  0.0256 -0.1778
#
# Columns 20 to 29
# -0.1307  0.1920 -0.0366  0.1381  0.0761  0.3310  0.1641  0.0248  0.1038  0.2358
#  0.1623  0.0459 -0.0603 -0.0770  0.3417 -0.0774  0.0017 -0.0010  0.1041 -0.0762
# -0.0118  0.1802 -0.0800  0.0092 -0.1061  0.0567  0.0840 -0.1473  0.1137 -0.1175
# -0.0282  0.1228 -0.0005 -0.0084  0.0592  0.1519  0.1550 -0.2064 -0.1885 -0.0044
#  0.0096 -0.1512  0.0034  0.1912  0.0145  0.1566 -0.1012  0.0683 -0.1044  0.2528
#  0.0310  0.1356 -0.0840  0.0057 -0.1527  0.0341  0.1368 -0.0258  0.1010  0.2276
#  0.1355  0.0087 -0.1092 -0.1747  0.1550  0.1861  0.0721  0.1140  0.1300 -0.0121
# -0.2025 -0.1942  0.1726  0.2351  0.0549  0.0109  0.1950  0.1142 -0.0423  0.1864
#  0.1668  0.0506  0.1451  0.0440  0.1820  0.1680  0.1911  0.1203  0.2184  0.1750
#  0.2493 -0.1141  0.0779  0.1572  0.2033  0.3275  0.1217  0.2684 -0.0397  0.0336
#  0.2630 -0.1308 -0.1183  0.0971 -0.0994  0.3066  0.1148 -0.0331  0.1215  0.0735
#  0.1860  0.0569 -0.1339  0.1949  0.2426  0.1354 -0.0464  0.1542 -0.0340  0.1628
# -0.1126 -0.0803  0.0897 -0.0199  0.0369 -0.1896  0.1429  0.1010 -0.0147 -0.0803
#  0.0393  0.0532  0.0437 -0.1698 -0.0400  0.0468 -0.1045  0.2480 -0.1270  0.0569
#  0.1054  0.0587 -0.0905 -0.1025 -0.0110 -0.1658  0.0167 -0.1938 -0.1639 -0.0730
# -0.2736 -0.0002  0.0193 -0.0053  0.1186  0.3088 -0.0679 -0.0158 -0.0544  0.2452
# -0.1116 -0.0873 -0.0158  0.2205  0.1215  0.1870  0.2136 -0.0174  0.0872  0.0064
#
# Columns 30 to 33
#  0.0850  0.2747  0.0549 -0.2345
#  0.1675 -0.0636  0.1224 -0.2383
# -0.1683  0.0675  0.0444  0.1111
# -0.0214 -0.1199  0.0916  0.1207
# -0.0657 -0.2670  0.1058  0.1922
#  0.1241  0.0813  0.1322  0.0131
#  0.1897  0.4531 -0.1463 -0.1972
#  0.0511 -0.2361  0.0753  0.2593
# -0.1113 -0.1112 -0.1809 -0.1294
# -0.2748  0.1679  0.0129 -0.0585
#  0.0364  0.0780  0.1435 -0.0311
# -0.1766  0.0930  0.2697 -0.0905
# -0.0698  0.0101  0.0195 -0.2648
# -0.0854 -0.0093 -0.0880 -0.0024
# -0.0989 -0.0513 -0.1189 -0.0306
# -0.0843 -0.1992  0.0791 -0.1381
# -0.1020 -0.0766 -0.1891 -0.1625
# [torch.FloatTensor of size 17x34]

# %% [markdown]
# ### 3.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 18, 3, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 18, 3, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 4. Twenty Hidden Layers, 17 Neurons Each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(34, 17)
        self.fc2 = torch.nn.Linear(17, 17)
        self.fc3 = torch.nn.Linear(17, 17)
        self.fc4 = torch.nn.Linear(17, 17)
        self.fc5 = torch.nn.Linear(17, 17)
        self.fc6 = torch.nn.Linear(17, 17)
        self.fc7 = torch.nn.Linear(17, 17)
        self.fc8 = torch.nn.Linear(17, 17)
        self.fc9 = torch.nn.Linear(17, 17)
        self.fc10 = torch.nn.Linear(17, 17)
        self.fc11 = torch.nn.Linear(17, 17)
        self.fc12 = torch.nn.Linear(17, 17)
        self.fc13 = torch.nn.Linear(17, 17)
        self.fc14 = torch.nn.Linear(17, 17)
        self.fc15 = torch.nn.Linear(17, 17)
        self.fc16 = torch.nn.Linear(17, 17)
        self.fc17 = torch.nn.Linear(17, 17)
        self.fc18 = torch.nn.Linear(17, 17)
        self.fc19 = torch.nn.Linear(17, 17)
        self.fc20 = torch.nn.Linear(17, 17)
        self.fc21 = torch.nn.Linear(17, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = self.fc21(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 4.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = ((34 + 1) * 17) + (((17 + 1) * 17) * 19) + ((17 + 1) * 1)

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 18, 4)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 4.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %%
model.fc1.weight
# Out:
# Parameter containing:
#
# Columns 0 to 9
#  0.0638  0.1347 -0.0068  0.0201 -0.0749  0.4300 -0.2599  0.0739 -0.0310  0.0483
#  0.1249  0.3730  0.1558  0.1654  0.0657 -0.2411 -0.0236 -0.1253 -0.1445  0.0984
#  0.0170 -0.0096 -0.0760  0.0994  0.0623  0.0605  0.1776 -0.0828  0.0945  0.2096
#  0.0797  0.2005 -0.2240  0.2013  0.0376  0.0122 -0.2040  0.2214  0.0944  0.0128
# -0.1352  0.0162 -0.0658  0.1634 -0.3023 -0.2244 -0.3303  0.0620  0.1531 -0.0545
# -0.0594 -0.0575  0.1986  0.0448  0.1974 -0.0384  0.0630  0.2081 -0.1834  0.1258
#  0.1414 -0.1932  0.0662  0.1871  0.0742 -0.1767  0.1499 -0.1827  0.0623  0.0285
# -0.0282  0.2335 -0.1891  0.2344  0.1146  0.1040  0.0008 -0.1503  0.1693 -0.0441
# -0.0222 -0.0660 -0.0188  0.2393  0.2736 -0.0771  0.0367  0.1834  0.0669 -0.0455
#  0.1172  0.0057  0.1564  0.1308  0.2913  0.1110 -0.0856  0.0366  0.1734  0.0238
#  0.0342  0.0167 -0.0853  0.0684 -0.3924 -0.0303 -0.2492  0.0111  0.0853 -0.0856
# -0.0228  0.0835  0.0984  0.0896 -0.0114 -0.4398 -0.1079  0.0126  0.0011  0.2434
#  0.0567 -0.2595 -0.1187  0.2208  0.0576  0.1311 -0.0145 -0.0724  0.0213  0.2579
#  0.2619  0.0951  0.2581  0.1214  0.0562  0.1598 -0.0877  0.1508  0.0769 -0.0884
#  0.0051  0.1836  0.0235  0.1212  0.1197 -0.2895  0.0023  0.1063  0.1993  0.0951
#  0.0073  0.0275 -0.0208  0.1019  0.2524  0.1823 -0.1675  0.0978  0.0390 -0.0716
# -0.0569  0.2596 -0.0141  0.0363  0.3640 -0.0542 -0.0365  0.0153  0.1339  0.0834
#
# Columns 10 to 19
#  0.2700  0.0028 -0.0694  0.0113 -0.0551 -0.0816  0.0915  0.0593  0.0943 -0.0824
#  0.1120  0.1547 -0.0310  0.1871 -0.2777 -0.1491 -0.0787 -0.0615 -0.0359  0.0780
# -0.1476  0.2074 -0.0912  0.1204  0.1175 -0.0675 -0.0508 -0.1035  0.1877 -0.0387
# -0.0249 -0.1974  0.0429  0.1872  0.1539  0.0342  0.0379  0.1065  0.1147  0.0486
#  0.0349 -0.0030  0.0756  0.0212  0.1046  0.3001  0.2253 -0.2665 -0.0710  0.0020
#  0.0696  0.1468 -0.0548 -0.2129 -0.0789  0.0945  0.2407 -0.0427  0.1589 -0.0233
#  0.1572 -0.0641 -0.0067 -0.1441  0.1884  0.1740  0.0786  0.0455 -0.0858 -0.0169
# -0.1455  0.0309 -0.0195  0.0891  0.1933 -0.0620  0.1867  0.0935  0.0104  0.0346
#  0.1453  0.1180  0.3190  0.0769  0.0326  0.0746  0.1126  0.0165 -0.0059 -0.1103
#  0.2216 -0.0160 -0.0351  0.0079  0.2153 -0.0938  0.1445  0.0484  0.0615  0.0339
# -0.0208  0.1095 -0.0039  0.0305  0.1441 -0.0369 -0.0188 -0.1823  0.0161 -0.0861
#  0.0159 -0.1254  0.1198 -0.1355  0.0565 -0.0442  0.0175  0.2285  0.2039  0.0279
# -0.0387 -0.1405 -0.0940 -0.0649  0.0565  0.0385 -0.2106 -0.1073 -0.0501  0.1519
# -0.1509  0.1802  0.0102  0.2687  0.0746  0.1632 -0.2027  0.0455  0.2276  0.0608
# -0.0467 -0.0863 -0.0121  0.0668  0.0424  0.0522  0.0601  0.2032 -0.0858 -0.0188
#  0.1666  0.2306 -0.0611 -0.0284 -0.0509 -0.1607  0.0731 -0.1486 -0.1118  0.1195
#  0.2203  0.1718  0.0752 -0.0998 -0.0695 -0.1059 -0.0712 -0.1819 -0.1247 -0.0550
#
# Columns 20 to 29
#  0.1490  0.2520  0.0195 -0.0819  0.1548  0.1172  0.0171  0.1282  0.0520 -0.0261
#  0.0213  0.0849  0.0511  0.0585  0.2213  0.2715  0.0211  0.0950  0.1219  0.1654
#  0.1491 -0.1159 -0.1414  0.1221  0.1026  0.0755  0.2301  0.0741 -0.0165  0.2426
# -0.0818 -0.0129  0.1979  0.0922  0.0479  0.0344 -0.1810  0.1135 -0.0347  0.0796
#  0.2220 -0.1074  0.0898 -0.0249  0.2039 -0.0948 -0.0734  0.0876  0.0336 -0.1900
# -0.0931  0.0848  0.0204  0.0761 -0.0067  0.0818  0.1304 -0.1125 -0.1911  0.2229
#  0.0452  0.0326  0.0802  0.2510  0.1802  0.0818  0.1509  0.0011 -0.0419  0.0826
# -0.0967  0.0311 -0.0258 -0.1469 -0.0573  0.1290  0.1542  0.1684 -0.0066  0.0220
# -0.0227  0.1734  0.0141  0.1241  0.1344  0.1462  0.1805  0.0708 -0.0340  0.0752
#  0.0283 -0.0935 -0.1894  0.0416  0.1403  0.1272  0.1697  0.1924  0.2004  0.1857
# -0.0282 -0.0837 -0.1807 -0.1459  0.0799 -0.2367 -0.0627 -0.1630  0.0632 -0.2565
#  0.1295 -0.1170 -0.2220  0.3034 -0.1243 -0.1020  0.0326  0.1356  0.0303 -0.0372
#  0.2993 -0.0976 -0.1005 -0.0346  0.1441  0.0959  0.0290  0.1614  0.2067  0.0012
# -0.0174 -0.1159 -0.0186  0.1363  0.3117  0.1980  0.0195  0.0369 -0.0780  0.1641
#  0.0069  0.2077 -0.0975  0.0390  0.1825  0.2419 -0.0119  0.0714  0.0088  0.1762
# -0.0560  0.0170 -0.0286 -0.1542 -0.1026 -0.0206  0.0082 -0.1735 -0.0592  0.1107
#  0.1289  0.0863  0.0181 -0.0519 -0.0663  0.2745  0.0462  0.1710  0.1210  0.1282
#
# Columns 30 to 33
#  0.1715 -0.0215  0.1834 -0.0624
# -0.1585 -0.0180  0.0390  0.1662
#  0.1153  0.1604 -0.0451 -0.1458
# -0.1996 -0.0283 -0.0308 -0.2491
#  0.0223  0.0031  0.1560 -0.3121
# -0.2050 -0.2403  0.1502  0.3604
#  0.1097 -0.2511  0.0363  0.1151
# -0.0476  0.0676  0.0430 -0.2110
#  0.0972  0.2259 -0.0602 -0.1543
# -0.1397 -0.1558  0.0073  0.1202
#  0.0435  0.0338 -0.2950 -0.0379
#  0.2276  0.1484  0.1432 -0.0719
#  0.2090  0.1470 -0.0960 -0.2212
# -0.0803 -0.0233 -0.0259 -0.1648
#  0.1929 -0.0318  0.3125 -0.2346
# -0.1206  0.1718  0.0841  0.1017
#  0.1264  0.1912 -0.0992 -0.0322
# [torch.FloatTensor of size 17x34]

# %% [markdown]
# ### 4.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 18, 4, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 18, 4, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 5. Twenty-Five Hidden Layers, 17 Neurons Each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(34, 17)
        self.fc2 = torch.nn.Linear(17, 17)
        self.fc3 = torch.nn.Linear(17, 17)
        self.fc4 = torch.nn.Linear(17, 17)
        self.fc5 = torch.nn.Linear(17, 17)
        self.fc6 = torch.nn.Linear(17, 17)
        self.fc7 = torch.nn.Linear(17, 17)
        self.fc8 = torch.nn.Linear(17, 17)
        self.fc9 = torch.nn.Linear(17, 17)
        self.fc10 = torch.nn.Linear(17, 17)
        self.fc11 = torch.nn.Linear(17, 17)
        self.fc12 = torch.nn.Linear(17, 17)
        self.fc13 = torch.nn.Linear(17, 17)
        self.fc14 = torch.nn.Linear(17, 17)
        self.fc15 = torch.nn.Linear(17, 17)
        self.fc16 = torch.nn.Linear(17, 17)
        self.fc17 = torch.nn.Linear(17, 17)
        self.fc18 = torch.nn.Linear(17, 17)
        self.fc19 = torch.nn.Linear(17, 17)
        self.fc20 = torch.nn.Linear(17, 17)
        self.fc21 = torch.nn.Linear(17, 17)
        self.fc22 = torch.nn.Linear(17, 17)
        self.fc23 = torch.nn.Linear(17, 17)
        self.fc24 = torch.nn.Linear(17, 17)
        self.fc25 = torch.nn.Linear(17, 17)
        self.fc26 = torch.nn.Linear(17, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = torch.nn.functional.relu(self.fc21(x))
        x = torch.nn.functional.relu(self.fc22(x))
        x = torch.nn.functional.relu(self.fc23(x))
        x = torch.nn.functional.relu(self.fc24(x))
        x = torch.nn.functional.relu(self.fc25(x))
        x = self.fc26(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 5.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = ((34 + 1) * 17) + (((17 + 1) * 17) * 24) + ((17 + 1) * 1)

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 18, 5)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 5.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %%
model.fc1.weight
# Out:
# Parameter containing:
#
# Columns 0 to 9
#  0.0999 -0.1621 -0.0583  0.1314  0.2330 -0.0279  0.0022 -0.1326  0.0539 -0.0966
#  0.0115  0.3954  0.0586  0.2017  0.1703 -0.1942  0.0942  0.1040 -0.0134 -0.1261
# -0.1491  0.1895  0.0002  0.1409  0.2868 -0.2663  0.1107 -0.0417 -0.0736 -0.0818
#  0.3214 -0.0642  0.0000  0.1967  0.2820 -0.0631 -0.0773  0.0413  0.0012  0.1020
# -0.0665 -0.1486  0.0747  0.0431  0.1686 -0.1579  0.0569  0.1472  0.0605  0.1401
#  0.1070 -0.0032  0.0096  0.1258  0.0773  0.1235  0.0234  0.1125  0.0775  0.1204
#  0.0934  0.3206 -0.1272  0.3870  0.0377 -0.1580 -0.0228 -0.0805  0.1689 -0.0440
#  0.0606  0.1951 -0.1306  0.1674 -0.2568 -0.2515  0.3057 -0.0787  0.0811 -0.1661
#  0.1086 -0.1892  0.1671  0.1602  0.2154 -0.0740  0.1049  0.2090  0.0662  0.0508
#  0.1040  0.0231  0.1250  0.1736  0.0248  0.1010  0.0373 -0.0024 -0.0401  0.1230
# -0.0576  0.2600  0.0476  0.0319  0.1584 -0.2209  0.2575  0.0584 -0.0552  0.0544
# -0.1285  0.0133 -0.0638  0.2017 -0.2271 -0.1637 -0.1816  0.2097  0.0043 -0.1574
# -0.0162  0.0153 -0.0395  0.2367  0.1265  0.0179 -0.0233 -0.0815  0.1502  0.1996
# -0.1045 -0.0515 -0.0102 -0.0154 -0.1808  0.2990  0.0757  0.0524  0.1556  0.0807
#  0.0320  0.2429 -0.0077  0.2858  0.2098  0.0147  0.0310 -0.0949  0.2628  0.0769
#  0.0988  0.1076  0.2150 -0.1798  0.0635  0.0516 -0.2078 -0.0376 -0.1108  0.1103
# -0.0611 -0.1594 -0.1702  0.1838  0.2051 -0.2223  0.1061 -0.1008 -0.0481  0.1324
#
# Columns 10 to 19
# -0.0284 -0.0866 -0.0181 -0.1358  0.1021  0.0749  0.1295  0.1812 -0.1072 -0.1070
# -0.0775 -0.0576  0.2313 -0.0602  0.1836 -0.1445  0.0180 -0.0756  0.1753 -0.0161
#  0.1321  0.1140  0.0226 -0.1659  0.1200  0.2303  0.0329 -0.0152 -0.0807 -0.1303
#  0.0521 -0.0575 -0.1710  0.0931 -0.1192  0.0308 -0.0708  0.1575 -0.0308  0.0234
#  0.1510 -0.0390  0.1806 -0.1714 -0.1584 -0.0865 -0.0839 -0.1522 -0.0294 -0.1041
#  0.0234  0.0448 -0.0498  0.2862 -0.2044 -0.0001 -0.0732  0.4055  0.1683 -0.0896
#  0.0551  0.1875  0.0344  0.1118 -0.1556 -0.0225 -0.0380 -0.0983  0.1406 -0.1259
#  0.1500  0.0361 -0.0457 -0.0806 -0.1715 -0.0618 -0.1039  0.1147  0.1871 -0.1381
# -0.0359  0.0386  0.0585  0.0082  0.0358  0.1631 -0.0801 -0.0135  0.0547  0.0858
#  0.1072  0.0570 -0.0081  0.0825  0.1301  0.1236 -0.0633 -0.2137 -0.0016  0.1626
#  0.0470  0.1688 -0.0127  0.0206 -0.0956 -0.1797  0.1241 -0.0443 -0.1055  0.0426
# -0.0804  0.2313 -0.0060  0.2042  0.1999  0.1845  0.1265 -0.3060 -0.0449  0.0147
# -0.0851  0.0474 -0.1651 -0.0714  0.0063  0.1277 -0.1639  0.1712  0.0244  0.0017
#  0.0728 -0.0667  0.1662 -0.0494 -0.0268 -0.1051  0.0805  0.1183 -0.1099 -0.0159
#  0.1097  0.0577 -0.0093  0.1873 -0.0784  0.0241  0.0093 -0.1498 -0.1031  0.1335
#  0.1341 -0.1407  0.0537  0.1433  0.1211  0.2837  0.0385 -0.1514  0.1736 -0.0602
#  0.1550  0.1544 -0.0937  0.0593  0.0153  0.0019  0.2508  0.1136  0.0161 -0.1891
#
# Columns 20 to 29
# -0.1987  0.0036  0.0572  0.0747  0.0315  0.2821  0.0534  0.0798 -0.0459  0.3002
# -0.0733 -0.0633  0.0919  0.2490  0.1752  0.1246  0.0433 -0.0638  0.1463 -0.0167
#  0.1079  0.1702  0.1147  0.1779  0.2351  0.0616  0.1572  0.1551  0.1999  0.2481
# -0.0883  0.0472  0.0900 -0.1361  0.0297  0.0412  0.2119 -0.1479 -0.0951  0.2248
#  0.0132  0.1035  0.0840  0.2156  0.2046  0.2782  0.0728 -0.1286 -0.0458  0.1240
#  0.0113  0.0081 -0.1767  0.2419  0.0881  0.0842  0.0782  0.1853  0.2440  0.2347
#  0.0127 -0.1154  0.0299 -0.0991  0.1002 -0.0001 -0.0620  0.2654  0.0528  0.2680
#  0.0165 -0.0114 -0.1433  0.0792 -0.0378 -0.0347 -0.1077 -0.0657 -0.0608 -0.0676
#  0.2054  0.1828  0.1297  0.2964  0.1308  0.0556 -0.0520  0.0066  0.1915  0.2304
# -0.0903  0.1264 -0.1754  0.1867  0.1320  0.1218  0.1949 -0.0751 -0.0555  0.0403
# -0.0154  0.1745 -0.1713 -0.1960  0.0816  0.2278 -0.0152  0.0071  0.1332  0.2241
#  0.1121  0.0220  0.0902 -0.1480  0.2027 -0.1880  0.0272  0.0883  0.0748 -0.1282
#  0.2311 -0.0161 -0.1887 -0.0590 -0.1302  0.2230  0.0764 -0.1080  0.0582 -0.0890
# -0.1575  0.2089  0.2281 -0.0772  0.2125  0.0333 -0.0249 -0.0409  0.0454 -0.1318
#  0.0043 -0.1010  0.0660  0.0013  0.2303  0.1408  0.1256  0.1031  0.1485  0.1011
#  0.2228  0.1830  0.1819  0.1080  0.0919 -0.1238 -0.0259  0.2139  0.0575 -0.1164
# -0.1643  0.0410  0.0116 -0.1272 -0.1865  0.0719  0.1282  0.0445  0.1635  0.1644
#
# Columns 30 to 33
# -0.1414  0.0009 -0.0305 -0.0671
#  0.0563  0.0282  0.0287  0.0150
#  0.0735  0.1798  0.0073  0.0025
# -0.2724 -0.2061  0.1333  0.2089
# -0.0154 -0.0665  0.0004  0.0157
#  0.1468  0.0829  0.0572 -0.0848
# -0.1659  0.1588 -0.0265 -0.2143
#  0.1112 -0.0766 -0.2892 -0.0652
# -0.1236 -0.1501 -0.2106 -0.2280
#  0.1099 -0.0649  0.0493  0.1479
#  0.0879  0.1988  0.1028 -0.0149
#  0.0429  0.0099  0.1497 -0.2730
#  0.1573  0.1915 -0.0055 -0.2902
#  0.1130 -0.0094  0.1030 -0.1172
#  0.0405 -0.0342 -0.0715 -0.2298
# -0.0388 -0.1211  0.1224 -0.1395
# -0.0865 -0.0726  0.0985 -0.0546
# [torch.FloatTensor of size 17x34]

# %% [markdown]
# ### 5.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 18, 5, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 18, 5, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 6. Thirty Hidden Layers, 17 Neurons Each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(34, 17)
        self.fc2 = torch.nn.Linear(17, 17)
        self.fc3 = torch.nn.Linear(17, 17)
        self.fc4 = torch.nn.Linear(17, 17)
        self.fc5 = torch.nn.Linear(17, 17)
        self.fc6 = torch.nn.Linear(17, 17)
        self.fc7 = torch.nn.Linear(17, 17)
        self.fc8 = torch.nn.Linear(17, 17)
        self.fc9 = torch.nn.Linear(17, 17)
        self.fc10 = torch.nn.Linear(17, 17)
        self.fc11 = torch.nn.Linear(17, 17)
        self.fc12 = torch.nn.Linear(17, 17)
        self.fc13 = torch.nn.Linear(17, 17)
        self.fc14 = torch.nn.Linear(17, 17)
        self.fc15 = torch.nn.Linear(17, 17)
        self.fc16 = torch.nn.Linear(17, 17)
        self.fc17 = torch.nn.Linear(17, 17)
        self.fc18 = torch.nn.Linear(17, 17)
        self.fc19 = torch.nn.Linear(17, 17)
        self.fc20 = torch.nn.Linear(17, 17)
        self.fc21 = torch.nn.Linear(17, 17)
        self.fc22 = torch.nn.Linear(17, 17)
        self.fc23 = torch.nn.Linear(17, 17)
        self.fc24 = torch.nn.Linear(17, 17)
        self.fc25 = torch.nn.Linear(17, 17)
        self.fc26 = torch.nn.Linear(17, 17)
        self.fc27 = torch.nn.Linear(17, 17)
        self.fc28 = torch.nn.Linear(17, 17)
        self.fc29 = torch.nn.Linear(17, 17)
        self.fc30 = torch.nn.Linear(17, 17)
        self.fc31 = torch.nn.Linear(17, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = torch.nn.functional.relu(self.fc21(x))
        x = torch.nn.functional.relu(self.fc22(x))
        x = torch.nn.functional.relu(self.fc23(x))
        x = torch.nn.functional.relu(self.fc24(x))
        x = torch.nn.functional.relu(self.fc25(x))
        x = torch.nn.functional.relu(self.fc26(x))
        x = torch.nn.functional.relu(self.fc27(x))
        x = torch.nn.functional.relu(self.fc28(x))
        x = torch.nn.functional.relu(self.fc29(x))
        x = torch.nn.functional.relu(self.fc30(x))
        x = self.fc31(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 6.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = ((34 + 1) * 17) + (((17 + 1) * 17) * 29) + ((17 + 1) * 1)

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 18, 6)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 6.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %%
model.fc1.weight
# Out:
# Parameter containing:
#
# Columns 0 to 9
#  0.1332 -0.2509  0.0324 -0.0341  0.3271  0.0598  0.1950  0.0280 -0.0059  0.1381
# -0.2874  0.1155 -0.0974  0.0725  0.2447 -0.0890  0.1815 -0.1539 -0.0922  0.0188
#  0.2225  0.1142 -0.0173  0.0764  0.1041  0.0617  0.1458  0.0286 -0.0683  0.1184
#  0.0643 -0.1826  0.0153  0.1787  0.1121  0.1240  0.1297  0.0114  0.1258  0.1312
#  0.0266  0.0943 -0.1474  0.2274 -0.3884  0.0431 -0.2565  0.0178  0.1089 -0.0368
#  0.0166 -0.0362 -0.3466  0.1541 -0.2278 -0.1416  0.1826  0.0590  0.0667 -0.2044
# -0.0848  0.0134 -0.1045  0.3261  0.2093  0.0503 -0.1712 -0.0998  0.2629 -0.1002
# -0.0048 -0.0714  0.0406 -0.0374  0.1606 -0.2808 -0.0464 -0.1845 -0.1031  0.1047
# -0.0372  0.1968 -0.1534  0.1547  0.1057  0.1058 -0.0898  0.1557  0.1553  0.1177
# -0.1055  0.1062  0.0771  0.3262 -0.0357 -0.3373  0.1028  0.0304 -0.0318 -0.0030
#  0.0294 -0.1260  0.1939  0.0385  0.0557 -0.1751 -0.1949  0.0585  0.0524  0.0395
#  0.0779  0.2588 -0.1306  0.0869  0.1909 -0.0547  0.1357  0.1714 -0.0605  0.0872
#  0.1056  0.0315  0.2004  0.0684  0.1904 -0.1603  0.1007  0.0626 -0.1833 -0.1151
#  0.1378 -0.3632 -0.0845  0.1879 -0.1006 -0.0295 -0.1872  0.0517  0.0941 -0.1094
#  0.1372  0.2448  0.1173 -0.0029  0.2086 -0.1157  0.1359  0.0274  0.0985 -0.0550
#  0.3080 -0.0372 -0.1656 -0.0040  0.1699 -0.1146 -0.0291 -0.0558  0.2068 -0.0274
# -0.0233 -0.0452 -0.0229 -0.0748 -0.1505  0.0844  0.0149  0.1556  0.0208 -0.0065
#
# Columns 10 to 19
# -0.0865  0.1715  0.1100 -0.0762  0.1560  0.0623 -0.0938 -0.0268 -0.1145 -0.0548
#  0.0881  0.0720 -0.0401 -0.1558  0.0917  0.0105 -0.0030  0.1060 -0.0708 -0.0543
# -0.2039 -0.1458  0.1524  0.0065  0.2350 -0.0688  0.1341 -0.1447 -0.0556  0.0306
#  0.0936  0.1010 -0.2411 -0.1373 -0.0326 -0.0064  0.1652  0.0729  0.1307 -0.0257
# -0.0421  0.1579  0.0090 -0.1046  0.1225 -0.0203 -0.0009  0.0960 -0.1132 -0.1634
#  0.0226 -0.0686  0.0728  0.1418 -0.0548  0.0480 -0.0403 -0.1696 -0.0037  0.1016
# -0.1734  0.1247 -0.1366  0.2545 -0.0843  0.0997 -0.0591  0.0400  0.0234  0.0810
#  0.2150  0.1394 -0.0104 -0.0585 -0.2870 -0.1419  0.0553 -0.1217 -0.0687  0.1652
# -0.0367 -0.0964 -0.0697 -0.0583 -0.0547  0.1349  0.0388  0.1084  0.0111 -0.1497
#  0.0970 -0.1645 -0.0724  0.0329  0.0998  0.0927  0.1392 -0.0158  0.1440 -0.0472
#  0.0812  0.1783 -0.0649 -0.0990 -0.0190 -0.0064 -0.0509 -0.0989 -0.1758  0.1367
#  0.2060 -0.0194  0.0155 -0.0182 -0.0218 -0.1265 -0.0713 -0.2056 -0.1242  0.0480
# -0.0103  0.0248  0.1697  0.0166 -0.0897 -0.0586 -0.0441 -0.0419  0.0615  0.0218
#  0.0439  0.1098 -0.0756 -0.0526  0.1441  0.1067  0.0815  0.0880  0.1264  0.1043
#  0.0593  0.1179  0.2394  0.0384  0.2239 -0.0944 -0.0197 -0.1053 -0.0248  0.0011
# -0.2294 -0.1274  0.2994  0.1771  0.0046 -0.0317  0.0525  0.0413  0.0039  0.1855
#  0.0647  0.1132  0.0277  0.1591  0.1812  0.1103  0.2052 -0.2868  0.1544  0.0134
#
# Columns 20 to 29
#  0.0907 -0.1793 -0.0238  0.0861  0.0518 -0.0793  0.0045 -0.1976 -0.1737  0.1652
#  0.0988  0.1968 -0.1251 -0.1215 -0.1273  0.1644  0.2235  0.0869 -0.1391  0.0330
# -0.0223  0.0358 -0.2270  0.0525 -0.0308 -0.0233 -0.0297  0.2171  0.1987  0.0041
# -0.0636  0.0910  0.0027  0.0813 -0.1193  0.0804  0.2003  0.0033 -0.0658  0.2315
#  0.0226 -0.0311 -0.0752  0.0912  0.0860 -0.2394 -0.0298 -0.0048 -0.1088 -0.1139
# -0.1799 -0.0307 -0.2311  0.1562  0.0536 -0.0784  0.0713 -0.0555  0.1132 -0.0416
# -0.0522  0.0423 -0.0443 -0.0651  0.0643  0.1413 -0.0410  0.0075 -0.0845 -0.0026
#  0.0969 -0.0683 -0.0007  0.1639  0.1683  0.0219 -0.0231  0.0355 -0.0589  0.1537
#  0.0064 -0.0380  0.1599 -0.0591  0.0776  0.0819 -0.0025  0.0728  0.0348  0.1964
# -0.1724  0.1072  0.0043  0.1012  0.2483  0.1965  0.2083  0.0814 -0.0468  0.1160
# -0.0321  0.1174 -0.0536 -0.1078 -0.0907  0.1610  0.2003  0.0206 -0.0191 -0.0179
#  0.0134 -0.1259 -0.0350  0.0194 -0.1077  0.1228  0.0670 -0.0339  0.1361  0.2168
# -0.1945  0.1211  0.0774  0.2134  0.1104 -0.1115  0.1455  0.0722 -0.0211  0.0538
# -0.0321 -0.0481  0.0183  0.1865 -0.0056  0.0768  0.1801 -0.0579  0.0156  0.0097
#  0.0660  0.0225 -0.0080  0.2353  0.2408 -0.0734 -0.0005  0.0314  0.1503  0.1977
# -0.0906  0.1952  0.0303 -0.1378  0.0205  0.0604 -0.2091  0.0899 -0.0496 -0.0250
#  0.1301  0.0029  0.0729  0.0330  0.2273 -0.1728 -0.0687  0.0333 -0.0198 -0.1188
#
# Columns 30 to 33
#  0.0756 -0.2294 -0.0531  0.1588
#  0.0023  0.3820 -0.1099 -0.1875
# -0.1313 -0.1405  0.1571  0.0224
# -0.1842 -0.1048 -0.0931  0.1637
#  0.0992  0.1126 -0.2470  0.0049
# -0.0272  0.0111 -0.2697 -0.0206
# -0.0875 -0.0503  0.0604 -0.1793
#  0.1230  0.1594 -0.0142  0.2257
# -0.1046 -0.2850 -0.0703 -0.1264
#  0.1109  0.2086  0.0524 -0.0794
#  0.0906  0.1421 -0.0286 -0.0298
# -0.0108 -0.0601  0.1634 -0.0752
# -0.1586 -0.0103  0.1027  0.2473
#  0.0004  0.0914 -0.2006 -0.1305
#  0.1078  0.1164 -0.1516 -0.1539
# -0.0318  0.1253  0.0221 -0.0698
#  0.1475 -0.0818  0.2592 -0.2384
# [torch.FloatTensor of size 17x34]

# %% [markdown]
# ### 6.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 18, 6, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 18, 6, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 7. Thirty-Five Hidden Layers, 17 Neurons Each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(34, 17)
        self.fc2 = torch.nn.Linear(17, 17)
        self.fc3 = torch.nn.Linear(17, 17)
        self.fc4 = torch.nn.Linear(17, 17)
        self.fc5 = torch.nn.Linear(17, 17)
        self.fc6 = torch.nn.Linear(17, 17)
        self.fc7 = torch.nn.Linear(17, 17)
        self.fc8 = torch.nn.Linear(17, 17)
        self.fc9 = torch.nn.Linear(17, 17)
        self.fc10 = torch.nn.Linear(17, 17)
        self.fc11 = torch.nn.Linear(17, 17)
        self.fc12 = torch.nn.Linear(17, 17)
        self.fc13 = torch.nn.Linear(17, 17)
        self.fc14 = torch.nn.Linear(17, 17)
        self.fc15 = torch.nn.Linear(17, 17)
        self.fc16 = torch.nn.Linear(17, 17)
        self.fc17 = torch.nn.Linear(17, 17)
        self.fc18 = torch.nn.Linear(17, 17)
        self.fc19 = torch.nn.Linear(17, 17)
        self.fc20 = torch.nn.Linear(17, 17)
        self.fc21 = torch.nn.Linear(17, 17)
        self.fc22 = torch.nn.Linear(17, 17)
        self.fc23 = torch.nn.Linear(17, 17)
        self.fc24 = torch.nn.Linear(17, 17)
        self.fc25 = torch.nn.Linear(17, 17)
        self.fc26 = torch.nn.Linear(17, 17)
        self.fc27 = torch.nn.Linear(17, 17)
        self.fc28 = torch.nn.Linear(17, 17)
        self.fc29 = torch.nn.Linear(17, 17)
        self.fc30 = torch.nn.Linear(17, 17)
        self.fc31 = torch.nn.Linear(17, 17)
        self.fc32 = torch.nn.Linear(17, 17)
        self.fc33 = torch.nn.Linear(17, 17)
        self.fc34 = torch.nn.Linear(17, 17)
        self.fc35 = torch.nn.Linear(17, 17)
        self.fc36 = torch.nn.Linear(17, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = torch.nn.functional.relu(self.fc21(x))
        x = torch.nn.functional.relu(self.fc22(x))
        x = torch.nn.functional.relu(self.fc23(x))
        x = torch.nn.functional.relu(self.fc24(x))
        x = torch.nn.functional.relu(self.fc25(x))
        x = torch.nn.functional.relu(self.fc26(x))
        x = torch.nn.functional.relu(self.fc27(x))
        x = torch.nn.functional.relu(self.fc28(x))
        x = torch.nn.functional.relu(self.fc29(x))
        x = torch.nn.functional.relu(self.fc30(x))
        x = torch.nn.functional.relu(self.fc31(x))
        x = torch.nn.functional.relu(self.fc32(x))
        x = torch.nn.functional.relu(self.fc33(x))
        x = torch.nn.functional.relu(self.fc34(x))
        x = torch.nn.functional.relu(self.fc35(x))
        x = self.fc36(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 7.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = ((34 + 1) * 17) + (((17 + 1) * 17) * 34) + ((17 + 1) * 1)

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 18, 7)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 7.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %%
model.fc1.weight
# Out:
# Parameter containing:
#
# Columns 0 to 9
#  0.1441  0.0681  0.0697  0.0920  0.2282 -0.0387  0.0784  0.1005 -0.0300 -0.0487
#  0.0481  0.1345 -0.0702 -0.0116 -0.1915 -0.2157 -0.1390  0.2075  0.0728 -0.0900
#  0.1245 -0.0081  0.0527  0.3809  0.0383  0.0828  0.1591  0.1579  0.0869 -0.0416
#  0.1243 -0.0577 -0.1208  0.1699  0.1909 -0.0903  0.2395  0.2017  0.0706  0.0834
#  0.1311  0.1918 -0.0474  0.2319  0.0612 -0.1141  0.1819 -0.0783  0.1054  0.0958
#  0.0488 -0.1137 -0.1428  0.1190 -0.1191 -0.2231  0.3117 -0.0296  0.0585 -0.1499
# -0.1179 -0.0041  0.0332  0.0967 -0.1906  0.1776 -0.2032  0.0227  0.1753 -0.0593
# -0.0558  0.0734  0.0965  0.1483  0.2141 -0.0146  0.0718 -0.0110 -0.0429 -0.1546
# -0.1040 -0.0432 -0.0866  0.1568  0.1356 -0.1530 -0.0443  0.0162  0.0028 -0.0753
#  0.2222 -0.1760 -0.0988 -0.2277  0.1988 -0.1314  0.0426  0.1307 -0.0915 -0.0372
#  0.1193 -0.0357 -0.1410 -0.1251 -0.1242 -0.0688  0.2779  0.1139  0.3077  0.0650
#  0.0288 -0.1495 -0.1194  0.1823  0.2748 -0.1973 -0.0840 -0.2421  0.1553  0.2155
#  0.0095  0.2414  0.2488  0.0182  0.2549 -0.2731  0.1016  0.0210 -0.0983 -0.0906
#  0.1585  0.1982 -0.0795  0.0972  0.0426  0.0728 -0.1375  0.0985  0.1483 -0.1443
# -0.1123  0.3034  0.1496 -0.0533  0.4123 -0.1101 -0.0176  0.1297  0.0637 -0.0151
# -0.1222 -0.0016  0.0481  0.0763  0.3128 -0.2241  0.2299 -0.1250  0.1330  0.0559
#  0.0355  0.2711  0.1628  0.1790  0.2649 -0.0592  0.0133 -0.1114  0.0770  0.0633
#
# Columns 10 to 19
# -0.1367  0.0852  0.0874 -0.1668  0.2183  0.0555 -0.0443  0.1414 -0.1308 -0.0082
#  0.1831  0.2010 -0.0096  0.1766 -0.0261  0.2279  0.2409 -0.1010  0.0251 -0.0328
#  0.1250  0.0354 -0.0084  0.0143 -0.2025  0.0672 -0.1052 -0.0766 -0.2551  0.1294
#  0.2151  0.0517 -0.0686 -0.1007  0.1271  0.0722  0.1512 -0.0861  0.1995 -0.1421
#  0.0674  0.0722 -0.0549  0.1887 -0.1301  0.0212 -0.0560 -0.0770  0.0101  0.0628
# -0.0047  0.0081 -0.0119  0.0625  0.0021  0.0330 -0.0914 -0.1503 -0.0568  0.0444
# -0.0559 -0.0246 -0.0513  0.0848  0.0901 -0.0185  0.1270 -0.2073  0.0290 -0.0358
#  0.1455  0.0626  0.0333 -0.0577 -0.0425 -0.1442 -0.0278 -0.3111 -0.2029 -0.0049
# -0.2176  0.0766  0.0974 -0.0937  0.0416 -0.1324  0.1067 -0.0309  0.0780 -0.0318
#  0.0943  0.1331 -0.0911  0.0646 -0.1189  0.2350  0.2796 -0.1395  0.0879 -0.0357
# -0.0957 -0.0004 -0.0104 -0.1000  0.2454  0.0198  0.0415  0.0018 -0.0592  0.0473
#  0.1548 -0.0545 -0.0993 -0.2053  0.1026  0.0744 -0.1597 -0.0193 -0.1307 -0.0131
#  0.0902  0.0255  0.0891 -0.0301  0.2358  0.1409 -0.0097  0.0579 -0.0072  0.1115
# -0.2985 -0.1664 -0.1498  0.1903  0.1410  0.0497  0.0302  0.0514  0.0288  0.0415
# -0.0453 -0.0220 -0.1012  0.2696 -0.1852 -0.0086 -0.0458 -0.1615 -0.1178 -0.1082
#  0.1481  0.0006  0.0408  0.0958 -0.1940 -0.1162  0.2038 -0.0183 -0.1138  0.1666
# -0.0495  0.0970  0.0878  0.0617 -0.0638 -0.0649  0.1836  0.0048  0.1295  0.0406
#
# Columns 20 to 29
# -0.0254 -0.0064  0.0737 -0.0586 -0.0530 -0.0018  0.1186  0.0037 -0.0340  0.0982
#  0.1228 -0.0161  0.0686  0.0753  0.1658 -0.2325 -0.0528  0.0974  0.0216 -0.2497
# -0.0265 -0.1105  0.0897 -0.1107  0.0478 -0.0191  0.0372 -0.3282 -0.2911  0.1289
# -0.1178  0.1313  0.0351  0.1802  0.0775  0.0012  0.1335  0.0261 -0.0917  0.2405
#  0.2386 -0.1409 -0.0935  0.0285 -0.0733  0.2082  0.0967  0.0079  0.0047 -0.0004
# -0.2111 -0.0476 -0.0946 -0.1523  0.0391 -0.0571 -0.1167 -0.0522 -0.0013 -0.0980
# -0.0819 -0.0054  0.1989 -0.0553  0.0602 -0.1296 -0.1161 -0.0475  0.0360 -0.0523
# -0.0174  0.0698  0.0473 -0.0476  0.0401 -0.0384  0.1303 -0.1457 -0.0288 -0.0127
# -0.1044  0.1332  0.0408 -0.1060 -0.1074  0.1249  0.1947 -0.1221 -0.0544  0.1096
#  0.0313 -0.0545  0.1191  0.0599  0.0267  0.1839  0.0249  0.1343  0.0053  0.1921
# -0.1371  0.1252 -0.2745 -0.0120  0.0837 -0.1796  0.1827 -0.1062 -0.1325  0.0223
# -0.0768  0.1146 -0.1714 -0.1394 -0.1031  0.1504  0.1808  0.1010  0.0131  0.0444
# -0.0857  0.2035  0.0531  0.2217  0.2283  0.0811 -0.0558  0.1493  0.0331  0.1458
# -0.2445 -0.1241  0.0152 -0.0389  0.2156  0.1307 -0.1068  0.1744  0.0364  0.0959
#  0.0285  0.1062 -0.0750  0.1177  0.1180  0.2249  0.0581 -0.0848  0.0769  0.1438
#  0.0184 -0.0203  0.0271  0.1081 -0.0700 -0.0423  0.0606  0.1565  0.1457  0.2482
#  0.0019 -0.0558  0.1315  0.0938  0.1632  0.2220  0.2285  0.0091  0.0279  0.0914
#
# Columns 30 to 33
# -0.2860 -0.2553 -0.0320 -0.1442
# -0.0023  0.0407 -0.0201 -0.2497
# -0.1117 -0.0806  0.0980  0.2158
# -0.0179 -0.0308  0.0159  0.1697
#  0.1410  0.2504 -0.0210 -0.2414
# -0.0718  0.0323 -0.3209  0.0184
#  0.1149  0.0278  0.4016 -0.0664
# -0.0479  0.0945 -0.1095  0.0379
# -0.1812 -0.1074  0.0611 -0.0674
# -0.1159 -0.2541  0.1770  0.0361
# -0.2355 -0.1220 -0.2330 -0.3148
# -0.1129  0.1385 -0.0289  0.0008
#  0.0318  0.2219 -0.0544 -0.1513
# -0.0982 -0.0493  0.0461 -0.1172
#  0.0218  0.1953  0.1108  0.1719
# -0.0067  0.1083  0.0266 -0.3022
# -0.0030 -0.0965 -0.1158  0.2278
# [torch.FloatTensor of size 17x34]

# %% [markdown]
# ### 7.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 18, 7, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 18, 7, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 8. Forty Hidden Layers, 17 Neurons Each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(34, 17)
        self.fc2 = torch.nn.Linear(17, 17)
        self.fc3 = torch.nn.Linear(17, 17)
        self.fc4 = torch.nn.Linear(17, 17)
        self.fc5 = torch.nn.Linear(17, 17)
        self.fc6 = torch.nn.Linear(17, 17)
        self.fc7 = torch.nn.Linear(17, 17)
        self.fc8 = torch.nn.Linear(17, 17)
        self.fc9 = torch.nn.Linear(17, 17)
        self.fc10 = torch.nn.Linear(17, 17)
        self.fc11 = torch.nn.Linear(17, 17)
        self.fc12 = torch.nn.Linear(17, 17)
        self.fc13 = torch.nn.Linear(17, 17)
        self.fc14 = torch.nn.Linear(17, 17)
        self.fc15 = torch.nn.Linear(17, 17)
        self.fc16 = torch.nn.Linear(17, 17)
        self.fc17 = torch.nn.Linear(17, 17)
        self.fc18 = torch.nn.Linear(17, 17)
        self.fc19 = torch.nn.Linear(17, 17)
        self.fc20 = torch.nn.Linear(17, 17)
        self.fc21 = torch.nn.Linear(17, 17)
        self.fc22 = torch.nn.Linear(17, 17)
        self.fc23 = torch.nn.Linear(17, 17)
        self.fc24 = torch.nn.Linear(17, 17)
        self.fc25 = torch.nn.Linear(17, 17)
        self.fc26 = torch.nn.Linear(17, 17)
        self.fc27 = torch.nn.Linear(17, 17)
        self.fc28 = torch.nn.Linear(17, 17)
        self.fc29 = torch.nn.Linear(17, 17)
        self.fc30 = torch.nn.Linear(17, 17)
        self.fc31 = torch.nn.Linear(17, 17)
        self.fc32 = torch.nn.Linear(17, 17)
        self.fc33 = torch.nn.Linear(17, 17)
        self.fc34 = torch.nn.Linear(17, 17)
        self.fc35 = torch.nn.Linear(17, 17)
        self.fc36 = torch.nn.Linear(17, 17)
        self.fc37 = torch.nn.Linear(17, 17)
        self.fc38 = torch.nn.Linear(17, 17)
        self.fc39 = torch.nn.Linear(17, 17)
        self.fc40 = torch.nn.Linear(17, 17)
        self.fc41 = torch.nn.Linear(17, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = torch.nn.functional.relu(self.fc21(x))
        x = torch.nn.functional.relu(self.fc22(x))
        x = torch.nn.functional.relu(self.fc23(x))
        x = torch.nn.functional.relu(self.fc24(x))
        x = torch.nn.functional.relu(self.fc25(x))
        x = torch.nn.functional.relu(self.fc26(x))
        x = torch.nn.functional.relu(self.fc27(x))
        x = torch.nn.functional.relu(self.fc28(x))
        x = torch.nn.functional.relu(self.fc29(x))
        x = torch.nn.functional.relu(self.fc30(x))
        x = torch.nn.functional.relu(self.fc31(x))
        x = torch.nn.functional.relu(self.fc32(x))
        x = torch.nn.functional.relu(self.fc33(x))
        x = torch.nn.functional.relu(self.fc34(x))
        x = torch.nn.functional.relu(self.fc35(x))
        x = torch.nn.functional.relu(self.fc36(x))
        x = torch.nn.functional.relu(self.fc37(x))
        x = torch.nn.functional.relu(self.fc38(x))
        x = torch.nn.functional.relu(self.fc39(x))
        x = torch.nn.functional.relu(self.fc40(x))
        x = self.fc41(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 8.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = ((34 + 1) * 17) + (((17 + 1) * 17) * 39) + ((17 + 1) * 1)

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 18, 8)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 8.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %%
model.fc1.weight
# Out:
# Parameter containing:
#
# Columns 0 to 9
# -0.0233  0.1007  0.0561  0.0079 -0.2844  0.0876 -0.1064  0.2859  0.1841  0.0197
#  0.2928  0.0178  0.1797  0.1856  0.3624  0.1727 -0.0577  0.0423  0.1008  0.1609
# -0.1118 -0.1089  0.1979  0.1213  0.2973 -0.1469  0.1394  0.1826  0.2335  0.1663
#  0.1669 -0.0767  0.2084  0.0768 -0.1817 -0.0844 -0.4551  0.1336  0.1018  0.2036
#  0.0814 -0.0442  0.0846 -0.1497 -0.1814 -0.1621  0.1540 -0.0702 -0.1458 -0.1567
#  0.1299  0.3867 -0.0072  0.4072  0.1937 -0.2080 -0.0243 -0.0138 -0.0491 -0.1355
#  0.0068  0.0011 -0.1517  0.2216 -0.2015 -0.2123  0.0986  0.0100  0.1151 -0.1847
# -0.0056  0.0822 -0.2877 -0.2033 -0.3370  0.1392  0.0918 -0.0504 -0.1764 -0.2150
#  0.0720 -0.0570  0.0604  0.4102  0.2852 -0.2996  0.1834 -0.0848  0.0182  0.0845
#  0.2030  0.2688 -0.1864  0.0768  0.0694 -0.1416  0.0184  0.0569  0.0700 -0.0860
#  0.0987 -0.0476  0.2485  0.0267 -0.4217  0.2738 -0.2632 -0.1729 -0.0239  0.0387
#  0.0523 -0.2047 -0.0299  0.0899  0.0686 -0.3402 -0.1806  0.2503  0.2198 -0.0267
#  0.2918 -0.0540  0.0057  0.3439  0.3307 -0.1630  0.1910 -0.0979  0.0008  0.1007
# -0.0982 -0.1272 -0.0371 -0.1145 -0.1217 -0.0275 -0.1217  0.1325  0.1097 -0.0891
#  0.0333  0.0152  0.2041  0.3974  0.2613 -0.2141  0.2562  0.2148 -0.0142  0.0561
#  0.0342  0.1629  0.1795  0.3594  0.2070 -0.0933 -0.1827  0.0097  0.2033  0.2323
#  0.0241  0.1285  0.0345  0.2212 -0.4317  0.1182 -0.1683 -0.0421  0.2266  0.0769
#
# Columns 10 to 19
#  0.0966  0.1015  0.1761  0.3398  0.1409  0.0387  0.0707  0.0311  0.1380  0.1177
#  0.0688  0.1102  0.1668  0.0152  0.0826 -0.0099  0.0821 -0.2732 -0.1298  0.1873
#  0.1541  0.0846  0.0964 -0.0869  0.0071  0.2230 -0.1263  0.0075  0.1534  0.0990
#  0.1369 -0.0901 -0.0845  0.2879  0.1126  0.2582  0.1472 -0.2059 -0.1034  0.1153
# -0.1643 -0.0558 -0.1712 -0.0163  0.2697  0.1151  0.0103 -0.2026 -0.2703 -0.1948
# -0.1073  0.1072 -0.0217 -0.0404 -0.1224  0.0028 -0.0415 -0.1102 -0.0811 -0.1020
#  0.1191  0.0526 -0.0005  0.1181 -0.1077  0.0442 -0.3278 -0.0941  0.0313  0.2527
#  0.1190 -0.0678  0.0523  0.0024 -0.0648 -0.0311  0.0503 -0.0410  0.0382 -0.0376
#  0.1007  0.0691 -0.0488  0.0716 -0.0425  0.1433  0.1183 -0.0344  0.1792 -0.0416
# -0.1593  0.0824  0.0406  0.0118  0.2122  0.0343 -0.0065  0.0764 -0.0550 -0.0077
# -0.0097  0.0603  0.0584  0.0391  0.0207  0.1376  0.1683 -0.0990  0.0174  0.0039
#  0.1068  0.2880 -0.0413  0.3049  0.0146  0.0686 -0.2119 -0.1132 -0.0112 -0.0849
#  0.1216  0.1141 -0.0596 -0.0869  0.1013 -0.0601 -0.1214 -0.2225 -0.0778  0.0700
#  0.0706  0.1172 -0.0403  0.2526  0.0240  0.1072  0.2055 -0.2266  0.1730 -0.2234
#  0.1994  0.1998 -0.0442  0.0545  0.2306  0.1409  0.0674  0.1115 -0.0742 -0.0820
#  0.0386 -0.0251  0.1971  0.0852 -0.1566 -0.0450 -0.0792 -0.1109 -0.1587  0.1589
# -0.0364  0.0715  0.2779 -0.1325 -0.0399  0.0224 -0.2588 -0.0429  0.2068  0.0235
#
# Columns 20 to 29
#  0.2302  0.0013  0.1588 -0.1503  0.0340 -0.1190  0.0449  0.0726  0.0725  0.0670
#  0.0311 -0.2697  0.0891  0.1917  0.0647  0.2333  0.2454  0.1799  0.1372  0.2066
#  0.0059  0.1125 -0.1866  0.2321  0.1053  0.3991  0.0438  0.0198 -0.0185  0.2997
#  0.1783  0.0696  0.1186 -0.1239 -0.0983 -0.0725 -0.0927 -0.0559 -0.0416 -0.1156
# -0.0675 -0.4142  0.0186 -0.0827 -0.0238 -0.1181 -0.1613 -0.1612 -0.1381  0.0534
# -0.1991  0.0913  0.1550 -0.1301  0.1688  0.1972  0.1822  0.0889 -0.1141  0.1982
# -0.1853 -0.1533 -0.0837 -0.0916 -0.0735 -0.0625  0.0259  0.2268  0.0123  0.0396
#  0.0075  0.0206 -0.0105 -0.1608  0.1186 -0.3540  0.0820 -0.0670 -0.2045 -0.3238
# -0.1231  0.1778  0.0959  0.0277  0.0436  0.4153  0.3613  0.0950  0.0727  0.2660
# -0.2118  0.0185  0.1983 -0.1721 -0.0525  0.2596 -0.0789 -0.0363 -0.0603  0.2028
#  0.0406  0.1516  0.2758 -0.1364 -0.0182  0.1003 -0.0154  0.0444 -0.1363  0.1143
# -0.1949 -0.1853 -0.2113  0.0218  0.1101  0.1611 -0.1169  0.0092  0.2448  0.0318
#  0.0191  0.0324  0.0378 -0.1370  0.1754  0.4555  0.3513  0.0335  0.0589  0.2429
#  0.1076 -0.0038  0.0695 -0.0332  0.0804  0.1457 -0.0104  0.2040  0.0783 -0.0942
#  0.1933  0.0221  0.0724  0.2803  0.0962  0.3727  0.0624  0.2324  0.0775  0.1587
#  0.1215  0.1090 -0.0272  0.1849  0.0635  0.1242  0.0395 -0.1173 -0.1045  0.3958
# -0.0694 -0.0795 -0.1131  0.0328  0.1643  0.0714 -0.1592 -0.0303 -0.1008  0.0910
#
# Columns 30 to 33
#  0.0039 -0.0679  0.4606 -0.2089
# -0.2175  0.0872 -0.0545  0.0075
#  0.1411  0.1940  0.1781 -0.0739
#  0.0002 -0.0593  0.1023 -0.1054
# -0.0863  0.1115  0.0146 -0.0513
# -0.0202  0.0650 -0.1079 -0.1505
# -0.0273 -0.1911 -0.4441  0.1796
#  0.1501  0.0601 -0.1649 -0.1735
# -0.0832  0.1617  0.1220  0.0732
# -0.1949 -0.2566  0.0903  0.0123
#  0.2312 -0.1178  0.2413 -0.0905
#  0.0262 -0.0674 -0.2223 -0.0136
# -0.0677 -0.0942  0.1359 -0.0682
#  0.1352 -0.0428  0.0739  0.0429
# -0.0550 -0.0488  0.0543  0.1011
#  0.1202  0.0947  0.0217 -0.2514
#  0.0987 -0.1244  0.1339 -0.0951
# [torch.FloatTensor of size 17x34]

# %% [markdown]
# ### 8.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 18, 8, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 18, 8, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 9. Forty-Five Hidden Layers, 17 Neurons Each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(34, 17)
        self.fc2 = torch.nn.Linear(17, 17)
        self.fc3 = torch.nn.Linear(17, 17)
        self.fc4 = torch.nn.Linear(17, 17)
        self.fc5 = torch.nn.Linear(17, 17)
        self.fc6 = torch.nn.Linear(17, 17)
        self.fc7 = torch.nn.Linear(17, 17)
        self.fc8 = torch.nn.Linear(17, 17)
        self.fc9 = torch.nn.Linear(17, 17)
        self.fc10 = torch.nn.Linear(17, 17)
        self.fc11 = torch.nn.Linear(17, 17)
        self.fc12 = torch.nn.Linear(17, 17)
        self.fc13 = torch.nn.Linear(17, 17)
        self.fc14 = torch.nn.Linear(17, 17)
        self.fc15 = torch.nn.Linear(17, 17)
        self.fc16 = torch.nn.Linear(17, 17)
        self.fc17 = torch.nn.Linear(17, 17)
        self.fc18 = torch.nn.Linear(17, 17)
        self.fc19 = torch.nn.Linear(17, 17)
        self.fc20 = torch.nn.Linear(17, 17)
        self.fc21 = torch.nn.Linear(17, 17)
        self.fc22 = torch.nn.Linear(17, 17)
        self.fc23 = torch.nn.Linear(17, 17)
        self.fc24 = torch.nn.Linear(17, 17)
        self.fc25 = torch.nn.Linear(17, 17)
        self.fc26 = torch.nn.Linear(17, 17)
        self.fc27 = torch.nn.Linear(17, 17)
        self.fc28 = torch.nn.Linear(17, 17)
        self.fc29 = torch.nn.Linear(17, 17)
        self.fc30 = torch.nn.Linear(17, 17)
        self.fc31 = torch.nn.Linear(17, 17)
        self.fc32 = torch.nn.Linear(17, 17)
        self.fc33 = torch.nn.Linear(17, 17)
        self.fc34 = torch.nn.Linear(17, 17)
        self.fc35 = torch.nn.Linear(17, 17)
        self.fc36 = torch.nn.Linear(17, 17)
        self.fc37 = torch.nn.Linear(17, 17)
        self.fc38 = torch.nn.Linear(17, 17)
        self.fc39 = torch.nn.Linear(17, 17)
        self.fc40 = torch.nn.Linear(17, 17)
        self.fc41 = torch.nn.Linear(17, 17)
        self.fc42 = torch.nn.Linear(17, 17)
        self.fc43 = torch.nn.Linear(17, 17)
        self.fc44 = torch.nn.Linear(17, 17)
        self.fc45 = torch.nn.Linear(17, 17)
        self.fc46 = torch.nn.Linear(17, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = torch.nn.functional.relu(self.fc21(x))
        x = torch.nn.functional.relu(self.fc22(x))
        x = torch.nn.functional.relu(self.fc23(x))
        x = torch.nn.functional.relu(self.fc24(x))
        x = torch.nn.functional.relu(self.fc25(x))
        x = torch.nn.functional.relu(self.fc26(x))
        x = torch.nn.functional.relu(self.fc27(x))
        x = torch.nn.functional.relu(self.fc28(x))
        x = torch.nn.functional.relu(self.fc29(x))
        x = torch.nn.functional.relu(self.fc30(x))
        x = torch.nn.functional.relu(self.fc31(x))
        x = torch.nn.functional.relu(self.fc32(x))
        x = torch.nn.functional.relu(self.fc33(x))
        x = torch.nn.functional.relu(self.fc34(x))
        x = torch.nn.functional.relu(self.fc35(x))
        x = torch.nn.functional.relu(self.fc36(x))
        x = torch.nn.functional.relu(self.fc37(x))
        x = torch.nn.functional.relu(self.fc38(x))
        x = torch.nn.functional.relu(self.fc39(x))
        x = torch.nn.functional.relu(self.fc40(x))
        x = torch.nn.functional.relu(self.fc41(x))
        x = torch.nn.functional.relu(self.fc42(x))
        x = torch.nn.functional.relu(self.fc43(x))
        x = torch.nn.functional.relu(self.fc44(x))
        x = torch.nn.functional.relu(self.fc45(x))
        x = self.fc46(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 9.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = ((34 + 1) * 17) + (((17 + 1) * 17) * 44) + ((17 + 1) * 1)

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 18, 9)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 9.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %%
model.fc1.weight
# Out:
# Parameter containing:
#
# Columns 0 to 9
# -0.1029  0.0026  0.1555 -0.0927  0.0016  0.3222 -0.0277 -0.0753  0.0375 -0.1307
# -0.1480  0.3168  0.1238  0.0200  0.0195 -0.2101 -0.1318 -0.2326  0.1071 -0.0669
#  0.0432  0.0654  0.0972  0.1572 -0.3584  0.0286 -0.0710  0.1419  0.0244  0.0258
#  0.3215  0.0192  0.0569 -0.0195  0.2114  0.0092  0.1838  0.0787  0.0381  0.1403
# -0.0423  0.2690  0.0946  0.2285  0.0825 -0.0098 -0.0599  0.0968  0.0939  0.0893
# -0.0303 -0.0672 -0.2154  0.0163 -0.1415 -0.2599  0.4258  0.0435  0.0697 -0.0069
#  0.1589  0.0584 -0.0576  0.3250  0.3007 -0.0419  0.2006  0.1301  0.1671  0.1494
# -0.0748  0.1335 -0.0400  0.3026  0.3683 -0.1352  0.0600 -0.0450 -0.0165  0.1956
#  0.1353 -0.1856 -0.1993  0.0400  0.2562 -0.1266  0.1594  0.2630  0.1473 -0.0220
#  0.0849 -0.0490  0.0125  0.0590 -0.1259 -0.1531 -0.2586  0.1560  0.2158 -0.2488
#  0.2509 -0.2001  0.0517 -0.2783 -0.2147  0.0207 -0.3081  0.0750 -0.0018 -0.0665
# -0.0604 -0.1776 -0.0389 -0.1698  0.0440  0.1239 -0.0598 -0.0092  0.0053  0.1831
#  0.0715  0.0702  0.2315  0.0992  0.2741 -0.2346 -0.0503 -0.0492  0.2341  0.0550
#  0.0241  0.1091  0.2208  0.1436  0.1834 -0.3254  0.1412 -0.0842 -0.1067  0.0763
#  0.0385  0.1526 -0.0477  0.2780  0.0071 -0.1752  0.1207 -0.0143  0.0878 -0.0270
#  0.0744  0.0353 -0.1920  0.0211 -0.3562 -0.1699  0.2544  0.0089 -0.0346 -0.2063
# -0.0056 -0.0179  0.0848  0.0357  0.1557 -0.2001  0.1227  0.0135 -0.0482  0.0037
#
# Columns 10 to 19
#  0.0502 -0.1586  0.0461 -0.1466 -0.1318 -0.0041 -0.0637  0.0064 -0.0736  0.0621
#  0.0289  0.0623 -0.0643  0.2166 -0.0945  0.0177 -0.0586 -0.1504 -0.2234  0.0209
#  0.0791 -0.0025  0.1171  0.1799  0.1223  0.2045 -0.0986 -0.1066  0.1232  0.1108
#  0.1671  0.0106 -0.1272  0.0496 -0.0363 -0.0361  0.1393  0.0630 -0.1077  0.0543
#  0.1108  0.1551 -0.1527 -0.1180 -0.2614 -0.1332 -0.1158 -0.1496 -0.2271  0.0137
# -0.1226  0.0778  0.0738  0.2153 -0.0205 -0.0221  0.0049 -0.1751 -0.1047  0.0616
# -0.1791  0.0791  0.0204 -0.1034 -0.0215  0.1999  0.1181  0.1895  0.0214 -0.1501
#  0.0726  0.1126  0.0396 -0.0609  0.1684 -0.0538 -0.1393 -0.1920  0.0129 -0.0329
# -0.0875  0.1144  0.2256  0.0140  0.0786  0.2834  0.0647 -0.0873 -0.1477  0.1277
#  0.1652  0.0320  0.0036  0.0083 -0.0121  0.2513  0.0487 -0.2651  0.0871 -0.0821
# -0.1434 -0.0426  0.0987  0.0705  0.0921 -0.1732 -0.0698  0.1027 -0.0339  0.1200
#  0.0528  0.0321  0.1087  0.1615  0.1359 -0.0237  0.1961 -0.2557  0.2308 -0.1353
#  0.1200  0.1872  0.1666 -0.1267  0.0528  0.1137  0.0542 -0.0816  0.2108 -0.0776
#  0.0680  0.1009  0.0454 -0.0970 -0.0342 -0.0430 -0.1182 -0.0234 -0.1292  0.1011
# -0.1717  0.0087 -0.1954  0.2173  0.1293 -0.1795  0.0784  0.0193  0.0351  0.0774
# -0.0514  0.0535 -0.0427  0.0926 -0.1516 -0.1136 -0.1900  0.0940 -0.0432 -0.0138
#  0.0573  0.0071  0.1703  0.1296  0.0317  0.0527  0.0358 -0.2682 -0.0938  0.1906
#
# Columns 20 to 29
# -0.1700 -0.0162  0.2291  0.0006  0.2142 -0.0255  0.0667  0.0535  0.0351 -0.2110
#  0.0016 -0.1706 -0.0437 -0.0460  0.0199  0.1860  0.0171 -0.0212 -0.0452  0.1800
# -0.0130  0.0010  0.1241 -0.2089  0.1394 -0.0682  0.0829 -0.1227  0.0092 -0.1086
#  0.1493 -0.1380  0.1008  0.0204  0.1263  0.2141  0.2662  0.1827  0.0797  0.0154
# -0.0005 -0.0995  0.0073  0.0252  0.0294  0.1550 -0.0344 -0.0093 -0.0539  0.2692
# -0.0978 -0.1545 -0.1672 -0.0232  0.1124 -0.0805 -0.0913  0.1547 -0.1372 -0.2043
# -0.0315  0.0103  0.1482 -0.1362  0.1369  0.0821  0.0858  0.0154 -0.0841  0.3266
#  0.0071  0.2006  0.0241 -0.1276  0.1462  0.2502  0.1800  0.0808  0.0239  0.1813
#  0.0733  0.1209  0.2328  0.0124  0.0555  0.2748  0.0403 -0.1049 -0.1068  0.1145
#  0.1829 -0.0066  0.1112 -0.1959  0.0670 -0.1854 -0.2009  0.1273  0.1947 -0.1065
#  0.0512 -0.0878  0.1133 -0.0849  0.1217 -0.2178 -0.0437 -0.1018 -0.2138  0.0771
#  0.2595  0.0420  0.0049 -0.0404  0.2970 -0.0596 -0.0477 -0.0559  0.1816 -0.2721
#  0.0248 -0.0168 -0.0492  0.2451  0.1026  0.3092  0.0032 -0.0488  0.0058 -0.0026
# -0.0618  0.0067 -0.1170 -0.0566 -0.0619  0.2459  0.0247  0.1553 -0.0679  0.0148
# -0.2509  0.0521 -0.0915 -0.0692  0.2065  0.1546 -0.0429  0.0795 -0.0960  0.2518
#  0.0109 -0.0978 -0.1177 -0.2309  0.1132  0.0262  0.0071 -0.1627 -0.0656 -0.0167
#  0.0956 -0.0124 -0.1371  0.0856  0.1802  0.2562  0.1809  0.1245 -0.0241  0.2875
#
# Columns 30 to 33
#  0.0603 -0.0692  0.2133 -0.2013
# -0.0521 -0.0042 -0.0800 -0.0972
# -0.0141  0.0386  0.3554 -0.1056
# -0.2456 -0.1784  0.1006  0.0782
# -0.1635  0.0007  0.0363  0.0844
# -0.0511 -0.0272 -0.4106 -0.0115
# -0.1754 -0.1562  0.0568 -0.2482
#  0.1534  0.2531 -0.0479 -0.0528
#  0.0894 -0.0590  0.1064  0.0604
# -0.0186 -0.0164  0.1845 -0.2024
# -0.1054 -0.2613  0.0814  0.2283
#  0.1342 -0.1092  0.0510 -0.2320
# -0.0316  0.0669 -0.1260 -0.0578
# -0.2277  0.0382  0.0734 -0.0666
# -0.0599  0.2235 -0.1787 -0.0797
# -0.0190 -0.0508 -0.3002 -0.1096
# -0.0043 -0.0408  0.1224 -0.1615
# [torch.FloatTensor of size 17x34]

# %% [markdown]
# ### 9.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 18, 9, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 18, 9, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 10. Fifty Hidden Layers, 17 Neurons Each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(34, 17)
        self.fc2 = torch.nn.Linear(17, 17)
        self.fc3 = torch.nn.Linear(17, 17)
        self.fc4 = torch.nn.Linear(17, 17)
        self.fc5 = torch.nn.Linear(17, 17)
        self.fc6 = torch.nn.Linear(17, 17)
        self.fc7 = torch.nn.Linear(17, 17)
        self.fc8 = torch.nn.Linear(17, 17)
        self.fc9 = torch.nn.Linear(17, 17)
        self.fc10 = torch.nn.Linear(17, 17)
        self.fc11 = torch.nn.Linear(17, 17)
        self.fc12 = torch.nn.Linear(17, 17)
        self.fc13 = torch.nn.Linear(17, 17)
        self.fc14 = torch.nn.Linear(17, 17)
        self.fc15 = torch.nn.Linear(17, 17)
        self.fc16 = torch.nn.Linear(17, 17)
        self.fc17 = torch.nn.Linear(17, 17)
        self.fc18 = torch.nn.Linear(17, 17)
        self.fc19 = torch.nn.Linear(17, 17)
        self.fc20 = torch.nn.Linear(17, 17)
        self.fc21 = torch.nn.Linear(17, 17)
        self.fc22 = torch.nn.Linear(17, 17)
        self.fc23 = torch.nn.Linear(17, 17)
        self.fc24 = torch.nn.Linear(17, 17)
        self.fc25 = torch.nn.Linear(17, 17)
        self.fc26 = torch.nn.Linear(17, 17)
        self.fc27 = torch.nn.Linear(17, 17)
        self.fc28 = torch.nn.Linear(17, 17)
        self.fc29 = torch.nn.Linear(17, 17)
        self.fc30 = torch.nn.Linear(17, 17)
        self.fc31 = torch.nn.Linear(17, 17)
        self.fc32 = torch.nn.Linear(17, 17)
        self.fc33 = torch.nn.Linear(17, 17)
        self.fc34 = torch.nn.Linear(17, 17)
        self.fc35 = torch.nn.Linear(17, 17)
        self.fc36 = torch.nn.Linear(17, 17)
        self.fc37 = torch.nn.Linear(17, 17)
        self.fc38 = torch.nn.Linear(17, 17)
        self.fc39 = torch.nn.Linear(17, 17)
        self.fc40 = torch.nn.Linear(17, 17)
        self.fc41 = torch.nn.Linear(17, 17)
        self.fc42 = torch.nn.Linear(17, 17)
        self.fc43 = torch.nn.Linear(17, 17)
        self.fc44 = torch.nn.Linear(17, 17)
        self.fc45 = torch.nn.Linear(17, 17)
        self.fc46 = torch.nn.Linear(17, 17)
        self.fc47 = torch.nn.Linear(17, 17)
        self.fc48 = torch.nn.Linear(17, 17)
        self.fc49 = torch.nn.Linear(17, 17)
        self.fc50 = torch.nn.Linear(17, 17)
        self.fc51 = torch.nn.Linear(17, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = torch.nn.functional.relu(self.fc21(x))
        x = torch.nn.functional.relu(self.fc22(x))
        x = torch.nn.functional.relu(self.fc23(x))
        x = torch.nn.functional.relu(self.fc24(x))
        x = torch.nn.functional.relu(self.fc25(x))
        x = torch.nn.functional.relu(self.fc26(x))
        x = torch.nn.functional.relu(self.fc27(x))
        x = torch.nn.functional.relu(self.fc28(x))
        x = torch.nn.functional.relu(self.fc29(x))
        x = torch.nn.functional.relu(self.fc30(x))
        x = torch.nn.functional.relu(self.fc31(x))
        x = torch.nn.functional.relu(self.fc32(x))
        x = torch.nn.functional.relu(self.fc33(x))
        x = torch.nn.functional.relu(self.fc34(x))
        x = torch.nn.functional.relu(self.fc35(x))
        x = torch.nn.functional.relu(self.fc36(x))
        x = torch.nn.functional.relu(self.fc37(x))
        x = torch.nn.functional.relu(self.fc38(x))
        x = torch.nn.functional.relu(self.fc39(x))
        x = torch.nn.functional.relu(self.fc40(x))
        x = torch.nn.functional.relu(self.fc41(x))
        x = torch.nn.functional.relu(self.fc42(x))
        x = torch.nn.functional.relu(self.fc43(x))
        x = torch.nn.functional.relu(self.fc44(x))
        x = torch.nn.functional.relu(self.fc45(x))
        x = torch.nn.functional.relu(self.fc46(x))
        x = torch.nn.functional.relu(self.fc47(x))
        x = torch.nn.functional.relu(self.fc48(x))
        x = torch.nn.functional.relu(self.fc49(x))
        x = torch.nn.functional.relu(self.fc50(x))
        x = self.fc51(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 10.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = ((34 + 1) * 17) + (((17 + 1) * 17) * 49) + ((17 + 1) * 1)

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 18, 10)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 10.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %%
model.fc1.weight
# Out:
# Parameter containing:
#
# Columns 0 to 9
# -0.0452 -0.1397  0.0709 -0.0183  0.0910  0.0830  0.0297 -0.0572 -0.0721 -0.0981
#  0.1349  0.0540  0.0643  0.1357  0.0021 -0.0409 -0.0054  0.0987  0.0791 -0.1520
# -0.1199  0.1611  0.0845  0.1085  0.1513  0.0662 -0.0397  0.0878 -0.0460  0.0124
#  0.0336 -0.0879 -0.1394  0.1392 -0.0343  0.0239 -0.0894 -0.1293 -0.1316 -0.0698
# -0.1527  0.1355  0.0690  0.1502  0.1007 -0.0178  0.1214 -0.0141 -0.0453 -0.0508
# -0.1227  0.0017  0.0100  0.0060  0.0349  0.0418  0.1326 -0.1182  0.0034 -0.1233
# -0.0192 -0.1099 -0.0149  0.0125 -0.0197  0.0183  0.1256 -0.0544 -0.0068 -0.0848
#  0.1216 -0.1477 -0.1158  0.1146  0.0121 -0.0869  0.0105  0.1569 -0.0949  0.0834
# -0.0748 -0.0418  0.0080 -0.0119  0.0144  0.0342 -0.0478  0.0760 -0.1133  0.0900
#  0.0190  0.0113  0.1441 -0.0210 -0.1623  0.1210 -0.1639  0.0799 -0.0597 -0.1000
# -0.0171 -0.0790  0.1650  0.0539 -0.0197  0.1414 -0.0086 -0.0634 -0.0049 -0.0140
# -0.0446 -0.0537  0.0426  0.0976 -0.1407  0.0544 -0.0289 -0.1204  0.0984  0.1145
# -0.1437 -0.1242  0.1270 -0.1004  0.0160 -0.0751  0.1147  0.1099 -0.0058  0.0038
#  0.0141 -0.0829 -0.1610 -0.0542  0.0703  0.0808  0.0094  0.0048  0.1067  0.0403
#  0.1304  0.0089  0.1232  0.1100  0.1437  0.0377  0.0585 -0.0660 -0.0756 -0.1329
# -0.0318  0.0265  0.0791 -0.1590  0.0332  0.1622 -0.1546 -0.0808 -0.0183  0.0871
# -0.1628 -0.1452 -0.0439  0.1128 -0.0919  0.1398 -0.1480  0.0808  0.1193  0.0200
#
# Columns 10 to 19
#  0.0337 -0.1189 -0.0094 -0.0299  0.1001  0.0312  0.0625 -0.0759 -0.0074  0.0376
#  0.0417 -0.1503 -0.1429 -0.0992  0.1039  0.1653 -0.0382 -0.1463  0.1404 -0.0650
# -0.0865 -0.1643  0.1258  0.0470 -0.0456  0.0970  0.0985 -0.0264 -0.1421 -0.0018
#  0.0338  0.0338  0.0575 -0.0855 -0.1498 -0.1208  0.0226  0.0093  0.1148 -0.0214
# -0.0624  0.0607  0.1527 -0.1358  0.0107 -0.1513 -0.0376 -0.1517  0.0111  0.1510
#  0.1648 -0.0969 -0.0240  0.1674 -0.0709 -0.0837  0.0492 -0.0754  0.0353  0.1087
# -0.0120  0.0538  0.1069 -0.1390 -0.1344  0.0891 -0.1015 -0.0872 -0.0765  0.0770
# -0.1132 -0.1293 -0.0380  0.0013  0.0864 -0.1688 -0.0051  0.0020  0.0033 -0.1097
#  0.0337 -0.1298 -0.0699 -0.0460 -0.0319 -0.0122 -0.1679  0.0137 -0.0512 -0.0205
# -0.0069  0.0607 -0.0190 -0.0545  0.1454  0.0515 -0.1409 -0.0244 -0.0182 -0.1562
#  0.0694 -0.1578 -0.0078 -0.0544 -0.0849 -0.0519 -0.0457  0.0446  0.0262  0.0483
#  0.0094  0.1673 -0.1231  0.1263  0.1126  0.1685 -0.1695  0.0401  0.0309  0.0714
# -0.0534  0.0596 -0.1297  0.1396 -0.0048 -0.0318 -0.0714 -0.0918 -0.0762  0.1090
# -0.1344 -0.0922 -0.1261  0.1456  0.0707 -0.0042  0.0972  0.0427  0.0205  0.0254
# -0.1177 -0.0677 -0.1675 -0.0283 -0.1002  0.1610  0.0623 -0.1311  0.0449 -0.0311
# -0.1007  0.1024  0.0163 -0.1172 -0.1573  0.0457 -0.1613  0.1017  0.1495 -0.0483
#  0.1268 -0.0821 -0.0688 -0.1059 -0.0207  0.0428 -0.1067  0.0042 -0.1182  0.0857
#
# Columns 20 to 29
# -0.0554  0.0623  0.0021  0.0758  0.1655 -0.1540 -0.1393  0.1546  0.0762 -0.0890
#  0.0831  0.0239 -0.0790 -0.1600 -0.0840  0.1628 -0.0156  0.1673 -0.0020 -0.0236
# -0.0466  0.0293  0.1530  0.0825  0.1453 -0.0163 -0.0293  0.0728 -0.0740 -0.0594
#  0.0938  0.1195 -0.1474  0.0756 -0.1394  0.0063 -0.1232  0.1575  0.0657 -0.0277
# -0.0090  0.0822 -0.1480  0.0171 -0.0402 -0.0019  0.0360 -0.1481 -0.0649 -0.0983
# -0.1213 -0.1284  0.0504 -0.0012  0.0391  0.1054 -0.0725 -0.1377 -0.0261 -0.1225
# -0.0794 -0.0268 -0.0732 -0.0462 -0.1678 -0.1609  0.1526  0.1469  0.0035 -0.1706
#  0.0380  0.1182 -0.0525 -0.0047 -0.0706  0.1628 -0.1059  0.1422  0.0038 -0.1524
# -0.1188  0.0886  0.1241  0.0988 -0.0005 -0.0006 -0.1612  0.1212 -0.0326 -0.0327
# -0.1430  0.1260  0.0077  0.0654 -0.0527 -0.1003  0.1364  0.1235  0.1494 -0.1687
# -0.1652  0.0282 -0.1230 -0.1061 -0.1332  0.0597 -0.1080 -0.0578  0.1486  0.1580
#  0.0090 -0.1298 -0.1144 -0.1019 -0.1008 -0.0944  0.0469  0.1678 -0.0516 -0.0734
#  0.0365  0.1673  0.0971 -0.0735  0.0190  0.0478 -0.1536 -0.0095  0.0022  0.1514
# -0.1011  0.0692  0.0454 -0.1360  0.1143 -0.0510  0.1582 -0.1622  0.0421  0.1065
# -0.0494  0.0693  0.1464 -0.0529  0.1500 -0.0874  0.0696 -0.0713 -0.0898 -0.1380
#  0.0396  0.1403 -0.1466  0.0045 -0.1053 -0.0675 -0.0926 -0.1126  0.0087 -0.0535
#  0.0027 -0.0823 -0.0237 -0.0819 -0.0037 -0.0152  0.1351 -0.0047 -0.1365 -0.0180
#
# Columns 30 to 33
#  0.0616 -0.1334 -0.0898  0.1198
#  0.1667  0.0525  0.0500  0.1498
#  0.0722 -0.0210 -0.1081 -0.0327
# -0.1377  0.0344 -0.1161 -0.0801
#  0.0115 -0.0196  0.1398 -0.0272
# -0.0317  0.0774  0.1233  0.0603
#  0.0223 -0.0662 -0.1427  0.0345
#  0.1664  0.1684 -0.0763 -0.0769
# -0.0985 -0.0620 -0.1490 -0.1400
# -0.1419  0.1084  0.1201  0.0243
# -0.1070  0.0260 -0.0819 -0.1077
# -0.0174 -0.0131  0.1123  0.1131
#  0.0892 -0.0813 -0.0165  0.1009
#  0.0654 -0.1507 -0.0777  0.0453
#  0.0430 -0.0922  0.1476 -0.1044
# -0.1406 -0.1357 -0.1441  0.1352
# -0.0318 -0.0282 -0.1678 -0.1204
# [torch.FloatTensor of size 17x34]

# %% [markdown]
# ### 10.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 18, 10, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 18, 10, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### Take a look at what we're saving

# %%
stored_cv_pred_df.head()
# Out:
#    predicted_values  notebook_number  model_number data_set  true_values
# 0          0.482564               18             1       cv     0.677117
# 1          0.732958               18             1       cv     0.484530
# 2          0.221265               18             1       cv     0.058780
# 3          0.803956               18             1       cv     0.876614
# 4          0.646722               18             1       cv     0.484530

# %%
stored_test_pred_df.head()
# Out:
#    predicted_values  notebook_number  model_number data_set  true_values
# 0          0.401851               18             1     test     0.356356
# 1          1.244477               18             1     test     1.132974
# 2          0.460782               18             1     test     0.578992
# 3          0.510708               18             1     test     0.578992
# 4          0.406883               18             1     test     0.578992

# %%
metrics_df
# Out:
#    Number of Parameters  R-squared  Mean Squared Error  \
# 0                  1837   0.422145            0.097828
# 1                  3367   0.426782            0.097043
# 2                  4897   0.429676            0.096553
# 3                  6427   0.432916            0.096005
# 4                  7957   0.413128            0.099355
# 5                  9487   0.434016            0.095819
# 6                 11017   0.421061            0.098012
# 7                 12547   0.420215            0.098155
# 8                 14077   0.425654            0.097234
# 9                 15607  -0.000019            0.169299
#
#    Mean Squared Error Over 1M  notebook_id  model_id
# 0                    0.192025           18         1
# 1                    0.197114           18         2
# 2                    0.188205           18         3
# 3                    0.212213           18         4
# 4                    0.231872           18         5
# 5                    0.195822           18         6
# 6                    0.198420           18         7
# 7                    0.209136           18         8
# 8                    0.187965           18         9
# 9                    0.595553           18        10

# %%
# Save the stored predictions and outcomes as a .csv
stored_cv_pred_df.to_csv("18_cv_perf.csv")

stored_test_pred_df.to_csv("18_test_perf.csv")

metrics_df.to_csv("18_metrics.csv")
