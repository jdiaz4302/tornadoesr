# %% [markdown]
# ## Setup

# %%
# Packages
import pandas as pd
import torch
from torch.autograd import Variable
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# %matplotlib inline
import pylab
import math
pylab.rcParams['figure.figsize'] = (8.25, 6)

# %% [markdown]
# Importing and formatting the training data

# %%
# Import data
tor_df = pd.read_csv("/home/jeremy/tornadoesr/data/raw/tor_train_set_no_zeros.csv")

# %%
# Seperating variables
# The outcomes
tornado_outcome = tor_df.iloc[:, [2]]


# Make sure variable is right
list(tornado_outcome)
# Out:
# ['DAMAGE_PROPERTY']

# %%
# The predictors
tornado_predictors = tor_df.iloc[:, 3:]


# Make sure the variables are right
list(tornado_predictors)
# Out:
# ['DURATION_SECONDS',
#  'BEGIN_LAT',
#  'BEGIN_LON',
#  'TOR_LENGTH',
#  'TOR_WIDTH',
#  'YEAR',
#  'MULTI_VORT_IND',
#  'OPEN_WATER_PROP',
#  'DEV_OPEN_PROP',
#  'DEV_LOW_PROP',
#  'DEV_MED_PROP',
#  'DEV_HIGH_PROP',
#  'BARREN_LAND_PROP',
#  'DECID_FOREST_PROP',
#  'EVERGR_FOREST_PROP',
#  'MIXED_FOREST_PROP',
#  'SHRUB_SCRUB_PROP',
#  'GRASS_LAND_PROP',
#  'PASTURE_HAY_PROP',
#  'CULT_CROPS_PROP',
#  'WOOD_WETLAND_PROP',
#  'HERB_WETLAND_PROP',
#  'PERC_MOB_HOMES',
#  'POP_DENS',
#  'MEDIAN_HOUSE_INC',
#  'MED_HOME_AGE',
#  'NUM_HOMES',
#  'PERC_WHITE',
#  'PERC_MALE',
#  'PERC_KIDS',
#  'PERC_HIGH_SCHOOL',
#  'PERC_ASSOC',
#  'PERC_BACH',
#  'PERC_GRAD',
#  'PERC_SENIOR',
#  'LOWERQ_HOME_VAL',
#  'MED_HOME_VAL',
#  'UPPERQ_HOME_VAL',
#  'PERC_POVERTY',
#  'GINI_INDEX',
#  'PERC_NOT_WORKING',
#  'PERC_COMM_30',
#  'PERC_COMM_EARLY',
#  'TOR_AREA',
#  'TOT_DEV_INT',
#  'TOT_WOOD_AREA',
#  'WOOD_DEV_INT',
#  'EXP_INC_AREA',
#  'TIME_SPLINE_1',
#  'TIME_SPLINE_2',
#  'TIME_SPLINE_3',
#  'TIME_SPLINE_4',
#  'TIME_SPLINE_5',
#  'TIME_SPLINE_6',
#  'TIME_SPLINE_7',
#  'TIME_SPLINE_8',
#  'JULIAN_SPLINE_1',
#  'JULIAN_SPLINE_2',
#  'JULIAN_SPLINE_3',
#  'JULIAN_SPLINE_4',
#  'JULIAN_SPLINE_5',
#  'JULIAN_SPLINE_6',
#  'JULIAN_SPLINE_7',
#  'JULIAN_SPLINE_8',
#  'JULIAN_SPLINE_9',
#  'JULIAN_SPLINE_10',
#  'JULIAN_SPLINE_11',
#  'JULIAN_SPLINE_12']

# %%
# Make the outcomes into a numpy array
outcome_array = tornado_outcome.values

# Makes that numpy array into a torch Tensor
outcome_Tensor = torch.from_numpy(outcome_array)


# Make the predictors into a numpy array
predictors_array = tornado_predictors.values

# Make that numpy array into a torch Tensor
predictors_Tensor = torch.from_numpy(predictors_array)


# Convert those DoubleTensors to FloatTensors
# Changing outcomes from a DoubleTensor to a FloatTensor
outcome_Tensor = outcome_Tensor.float()

# Changing predictors too
predictors_Tensor = predictors_Tensor.float()

# %% [markdown]
# Now the cross-validation data

# %%
# Import cross-validation data
cv_df = pd.read_csv("/home/jeremy/tornadoesr/data/raw/tor_cv_set_no_zeros.csv")


# Get the outcomes
cv_outcome = cv_df.iloc[:, [2]]

# Convert the pandas column to a ndarray and then into a FloatTensor
cv_outcome_Tensor = torch.from_numpy(cv_outcome.values).float()


# Make sure the variable is right
list(cv_outcome)
# Out:
# ['DAMAGE_PROPERTY']

# %%
# Get the validation set predictors
cv_predictors = cv_df.iloc[:, 3:]

# Make the validation set predictors into a numpy array
cv_predictors_Tensor = torch.from_numpy(cv_predictors.values).float()


# Make sure the variables are right
list(cv_predictors)
# Out:
# ['DURATION_SECONDS',
#  'BEGIN_LAT',
#  'BEGIN_LON',
#  'TOR_LENGTH',
#  'TOR_WIDTH',
#  'YEAR',
#  'MULTI_VORT_IND',
#  'OPEN_WATER_PROP',
#  'DEV_OPEN_PROP',
#  'DEV_LOW_PROP',
#  'DEV_MED_PROP',
#  'DEV_HIGH_PROP',
#  'BARREN_LAND_PROP',
#  'DECID_FOREST_PROP',
#  'EVERGR_FOREST_PROP',
#  'MIXED_FOREST_PROP',
#  'SHRUB_SCRUB_PROP',
#  'GRASS_LAND_PROP',
#  'PASTURE_HAY_PROP',
#  'CULT_CROPS_PROP',
#  'WOOD_WETLAND_PROP',
#  'HERB_WETLAND_PROP',
#  'PERC_MOB_HOMES',
#  'POP_DENS',
#  'MEDIAN_HOUSE_INC',
#  'MED_HOME_AGE',
#  'NUM_HOMES',
#  'PERC_WHITE',
#  'PERC_MALE',
#  'PERC_KIDS',
#  'PERC_HIGH_SCHOOL',
#  'PERC_ASSOC',
#  'PERC_BACH',
#  'PERC_GRAD',
#  'PERC_SENIOR',
#  'LOWERQ_HOME_VAL',
#  'MED_HOME_VAL',
#  'UPPERQ_HOME_VAL',
#  'PERC_POVERTY',
#  'GINI_INDEX',
#  'PERC_NOT_WORKING',
#  'PERC_COMM_30',
#  'PERC_COMM_EARLY',
#  'TOR_AREA',
#  'TOT_DEV_INT',
#  'TOT_WOOD_AREA',
#  'WOOD_DEV_INT',
#  'EXP_INC_AREA',
#  'TIME_SPLINE_1',
#  'TIME_SPLINE_2',
#  'TIME_SPLINE_3',
#  'TIME_SPLINE_4',
#  'TIME_SPLINE_5',
#  'TIME_SPLINE_6',
#  'TIME_SPLINE_7',
#  'TIME_SPLINE_8',
#  'JULIAN_SPLINE_1',
#  'JULIAN_SPLINE_2',
#  'JULIAN_SPLINE_3',
#  'JULIAN_SPLINE_4',
#  'JULIAN_SPLINE_5',
#  'JULIAN_SPLINE_6',
#  'JULIAN_SPLINE_7',
#  'JULIAN_SPLINE_8',
#  'JULIAN_SPLINE_9',
#  'JULIAN_SPLINE_10',
#  'JULIAN_SPLINE_11',
#  'JULIAN_SPLINE_12']

# %% [markdown]
# Now the test set data

# %%
# Import the test set data
test_df = pd.read_csv("/home/jeremy/tornadoesr/data/raw/tor_test_set_no_zeros.csv")


# Get the outcomes
test_outcome = test_df.iloc[:, [2]]

# Convert the pandas column to a ndarray and then into a FloatTensor
test_outcome_Tensor = torch.from_numpy(test_outcome.values).float()


# Make sure the variable is right
list(test_outcome)
# Out:
# ['DAMAGE_PROPERTY']

# %%
# Get the test set predictors
test_predictors = test_df.iloc[:, 3:]

# Make the test set predictors into a numpy array
test_predictors_Tensor = torch.from_numpy(test_predictors.values).float()


# Make sure the variables are right
list(test_predictors)
# Out:
# ['DURATION_SECONDS',
#  'BEGIN_LAT',
#  'BEGIN_LON',
#  'TOR_LENGTH',
#  'TOR_WIDTH',
#  'YEAR',
#  'MULTI_VORT_IND',
#  'OPEN_WATER_PROP',
#  'DEV_OPEN_PROP',
#  'DEV_LOW_PROP',
#  'DEV_MED_PROP',
#  'DEV_HIGH_PROP',
#  'BARREN_LAND_PROP',
#  'DECID_FOREST_PROP',
#  'EVERGR_FOREST_PROP',
#  'MIXED_FOREST_PROP',
#  'SHRUB_SCRUB_PROP',
#  'GRASS_LAND_PROP',
#  'PASTURE_HAY_PROP',
#  'CULT_CROPS_PROP',
#  'WOOD_WETLAND_PROP',
#  'HERB_WETLAND_PROP',
#  'PERC_MOB_HOMES',
#  'POP_DENS',
#  'MEDIAN_HOUSE_INC',
#  'MED_HOME_AGE',
#  'NUM_HOMES',
#  'PERC_WHITE',
#  'PERC_MALE',
#  'PERC_KIDS',
#  'PERC_HIGH_SCHOOL',
#  'PERC_ASSOC',
#  'PERC_BACH',
#  'PERC_GRAD',
#  'PERC_SENIOR',
#  'LOWERQ_HOME_VAL',
#  'MED_HOME_VAL',
#  'UPPERQ_HOME_VAL',
#  'PERC_POVERTY',
#  'GINI_INDEX',
#  'PERC_NOT_WORKING',
#  'PERC_COMM_30',
#  'PERC_COMM_EARLY',
#  'TOR_AREA',
#  'TOT_DEV_INT',
#  'TOT_WOOD_AREA',
#  'WOOD_DEV_INT',
#  'EXP_INC_AREA',
#  'TIME_SPLINE_1',
#  'TIME_SPLINE_2',
#  'TIME_SPLINE_3',
#  'TIME_SPLINE_4',
#  'TIME_SPLINE_5',
#  'TIME_SPLINE_6',
#  'TIME_SPLINE_7',
#  'TIME_SPLINE_8',
#  'JULIAN_SPLINE_1',
#  'JULIAN_SPLINE_2',
#  'JULIAN_SPLINE_3',
#  'JULIAN_SPLINE_4',
#  'JULIAN_SPLINE_5',
#  'JULIAN_SPLINE_6',
#  'JULIAN_SPLINE_7',
#  'JULIAN_SPLINE_8',
#  'JULIAN_SPLINE_9',
#  'JULIAN_SPLINE_10',
#  'JULIAN_SPLINE_11',
#  'JULIAN_SPLINE_12']

# %% [markdown]
# Importing previous data stage to undo data processing

# %%
old_df = pd.read_csv('/home/jeremy/tornadoesr/data/raw/tor_data_inflation_adj.csv')

log_xform_old_damages = np.log(old_df['DAMAGE_PROPERTY'] + 1)
old_sd = np.std(log_xform_old_damages)
old_mu = np.mean(log_xform_old_damages)

# %% [markdown]
# ## 1. Five hidden layers, 34 neurons each

# %% [markdown]
# Define the model architecture

# %%
number_input = tornado_predictors.shape[1]
hidden_size = int(np.round(number_input / 2))
number_input, hidden_size
# Out:
# (68, 34)

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(number_input, hidden_size)
        self.fc2 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc3 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc4 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc5 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc6 = torch.nn.Linear(hidden_size, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = self.fc6(x)
        return(x)


# Make it
model = Net()

# %% [markdown]
# Define the loss function

# %%
loss_fn = torch.nn.MSELoss(reduction = 'mean')

# %% [markdown]
# Defining a function to setup and train the models. It will also produce a loss versus iteration plot

# %%
def train_neural_net(model, train_outcomes, train_inputs,
                     cv_outcomes, cv_inputs):
    
    # This function will train the neural network and produce a loss versus iteration plot
    # model = the model architecture, a Net class
    # train_outcomes = the right answers, PyTorch Tensor
    # train_inputs = what we're using to get to the right answers, PyTorch Tensor
    # cv_outcomes = the right answers of the new data, PyTorch Tensor
    # cv_inputs = what we're using to get the new right answers, PyTorch Tensor
    # Returns a plot and a trained Net
    
    
    # Make the outcomes into a Torch Variable
    outcome_Variable = Variable(train_outcomes)
    
    # Make the cv outcomes into a Torch Variable
    cv_outcome_Variable = Variable(cv_outcomes,
                                   requires_grad = False)
    
    # Make the predictors into a Torch Variable
    predictors_Variable = Variable(train_inputs,
                                   requires_grad = False)
    
    # Make the cv predictors into a Torch Variable
    cv_predictors_Variable = Variable(cv_inputs,
                                      requires_grad = False)
    
    
    # Make an empty list to add to for each iteration
    current_loss_value_mini = []
    
    # For the cv too
    current_cv_loss_value = []
    
    
    # Set the optimizer
    optimizer = torch.optim.Adagrad(model.parameters(), lr = 1e-2)
    
    
    # Train the neural network
    for t in range(20000):
        
        # Get the current mini-batch indices
        indices = torch.randperm(len(predictors_Tensor))[0:50]
        
        # Get the current mini-batches
        predictors_mini = predictors_Variable[indices]
        outcome_mini = outcome_Variable[indices]
        
        # Get the current predictions
        current_pred_mini = model(predictors_mini)
        cv_pred = model(cv_predictors_Variable)
        
        # Compute current losses and and append that to the empty list
        current_loss_mini = loss_fn(current_pred_mini, outcome_mini)
        current_loss_value_mini.append(current_loss_mini.item())
        
        current_cv_loss = loss_fn(cv_pred, cv_outcome_Variable)
        current_cv_loss_value.append(current_cv_loss.item())
        
        # Zero the gradients before backwards pass
        optimizer.zero_grad()
        
        # Backwards pass
        current_loss_mini.backward()
        
        # Update model parameters
        optimizer.step()
    
    
    # Get iterations as a list for x-axis of plot
    iterations = list(range(0, 20000))
    
    
    # Plot loss versus iteration
    plt.plot(iterations, current_loss_value_mini)
    plt.plot(iterations, current_cv_loss_value, "r-")
    plt.xlabel("Iteration", size = 14)
    plt.ylabel("Loss Value", size = 14)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.title("How'd the Optimizing Go?", size = 16)

# %% [markdown]
# Train the first model.
#
# The plot will display how well it optimized. The blue line is the mini batch values that the model was optimized on, while the red line is new (cross-validation) data.

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %% [markdown]
# How'd the model perform on the data used to make it?

# %%
def plot_train_perf(train_predictors, train_obs):
    
    # Plots how well the model performs on training data
    # train_predictors = the values that the model predicts from, PyTorch Tensor
    # train_obs = what the model would ideally predict, PyTorch Tensor
    # Returns a plot
    
    
    # Get the predictions
    train_predictions = model(Variable(train_predictors, requires_grad = False))
    
    # Convert that to a numpy array
    train_predictions = train_predictions.data.numpy()
    
    # Put it in log-transformed scale and convert it to a list
    train_predictions = (train_predictions*old_sd + old_mu).tolist()
    
    
    # Put the observed outcomes in log-transformed scale
    # and convert it to a list
    train_obs = (train_obs.numpy()*old_sd + old_mu).tolist()
    
    
    # Plot it
    plt.scatter(train_obs, train_predictions, facecolors = "none", edgecolors = "k")
    axes = plt.gca()
    axes.set_xlim([-1, 24])
    axes.set_ylim([-1, 24])
    axes.set_xticks([0, 3, 6, 9, 12, 15, 18, 21, 24])
    axes.set_yticks([0, 3, 6, 9, 12, 15, 18, 21, 24])
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.plot([-1, 24], [-1, 24], 'k-', lw = 2)
    axes.set_xlabel("Observed (Log-Transformed US Dollars + 1)", size = 14)
    axes.set_ylabel("Predicted (Log-Transformed US Dollars + 1)", size = 14)
    axes.set_title("Model Performance on Training Data", size = 16)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 1.1 Performance Metrics

# %% [markdown]
# We're really interested in how it does on new data, so let's get some metrics of its performance on the new data.
#
# First: Mean squared error (MSE)

# %%
def compute_MSE(predictors, observed_outcomes):
    
    # Computes the mean squared error of the model
    # predictors = the variables and values used in prediction
    # observed_outcomes = what the prediction would ideally yield
    # Returns a PyTorch Variable
    
    
    # Get the validation set predictions
    cv_predictions = model(Variable(predictors, requires_grad = False))
    
    # Get the validation set outcomes
    cv_outcomes = Variable(observed_outcomes)
    
    
    # Get the loss - (total) residual sum of squares
    total_SE = loss_fn(cv_predictions, cv_outcomes)
    
    # Average that to get mean square error
    mean_SE = total_SE
    return(mean_SE)

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# Second: MSE for observed values over 1 million dollars

# %%
def compute_MSE_over_1mil(predictors, observed_outcomes):
    
    # Computes the mean squared error on observed values of over 1 million dollars
    # predictors = the variables and values used in prediction, PyTorch Tensor
    # observed_outcomes = what the prediction would ideally yield, PyTorch Tensor
    # Returns a PyTorch Variable
    
    
    # Getting the model-ready equivalent of 1 million
    one_million = (np.log(1e6 + 1) - old_mu) / old_sd
    
    # Combining predictions and observations into a DataFrame
    df = pd.DataFrame(model(Variable(predictors)).data.numpy())
    df.columns = ['predicted']
    df['observed'] = observed_outcomes.numpy()
    
    # Only keeping rows which contain observed values greater than 1 million dollars
    df = df.loc[df['observed'] >= one_million]
    
    # Making those columns model-ready
    predicted = Variable(torch.from_numpy(np.asarray(df['predicted'])))
    observed = Variable(torch.from_numpy(np.asarray(df['observed'])))
    
    # Get the MSE
    total_SE = loss_fn(predicted, observed)
    mean_SE = total_SE
    return(mean_SE)

# %%
MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# Third: R<sup>2</sup> (R-squared)

# %%
def compute_R_squared(predictors, observed_outcomes):
    
    # Computes R-squared of the model
    # predictors = the variables and values used in prediction, PyTorch Tensor
    # observed_outcomes = what the prediction would ideally yield, PyTorch Tensor
    # Returns a PyTorch Variable
    
    
    # Get the mean of the observed outcomes
    observed_mean = (sum(observed_outcomes) / len(observed_outcomes)).numpy()[0]
    
    # Fill an ndarray with that
    valid_outcomes_mean = np.repeat(observed_mean, len(observed_outcomes))
    
    # Convert that to a Variable
    valid_outcomes_mean = Variable(torch.from_numpy(valid_outcomes_mean))
    
    
    # Compute total sum of squares
    TSS = loss_fn(valid_outcomes_mean, Variable(observed_outcomes))
    
    
    # Compute residual sum of squares
    RSS = loss_fn(model(Variable(predictors)), Variable(observed_outcomes))
    
    
    # Compute R-squared
    R_squared = 1 - (RSS / TSS)
    return(R_squared)

# %%
R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# How many parameters did it take to achieve that?

# %%
Number_of_Parameters = (((number_input + 1) * hidden_size) +
                        (((hidden_size + 1) * hidden_size) * 4) +
                        ((hidden_size + 1) * 1))

# %% [markdown]
# #### Save these metrics

# %%
def save_metrics(Num_of_param, r_squared, mean_square_error, mse_over_1mil, notebook_id, model_id):
    
    # Saves the number of parameters, R-squared, MSE, MSE on observations over 1 million,
    #    along with a notebook and model identifier
    # The following inputs are PyTorch Variables: r_squared, mean_square_error, and mse_over_1mil
    # The following inputs are numbers: Num_of_param, notebook_id, model_id
    # Returns this as a DataFrame
    
    
    # Make the DataFrame, starting with the Number of Parameters as a sole column
    df = pd.DataFrame([Num_of_param])
    
    # Rename the column
    df.columns = ['Number of Parameters']
    
    
    # Add on R-squared and rename the column
    r_squared = r_squared.data.numpy().tolist()
    df['R-squared'] = r_squared
    
    # Add on MSE and rename the column
    mean_square_error = mean_square_error.data.numpy().tolist()
    df['Mean Squared Error'] = mean_square_error
    
    # Add on MSE on observations over 1 million and rename the column
    mse_over_1mil = MSE_over_1mil.data.numpy().tolist()
    df['Mean Squared Error Over 1M'] = mse_over_1mil
    
    # Add the notebook and model identifier
    df['notebook_id'] = [notebook_id]
    df['model_id'] = [model_id]
    return(df)

# %%
metrics_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 17, 1)
metrics_df
# Out:
#    Number of Parameters  R-squared  Mean Squared Error  \
# 0                  7141   0.376656            0.106387
#
#    Mean Squared Error Over 1M  notebook_id  model_id
# 0                    0.216169           17         1

# %% [markdown]
# ### 1.2 Performance Visualization

# %% [markdown]
# In log-transformed space, plot predicted values versus observed values for new data

# %%
def plot_cross_valid_perf(cv_predictors, cv_obs):
    
    # Plots how well the model performs on new data
    # cv_pred = the values that the model predicts from, PyTorch Tensor
    # cv_obs = what the model would ideally predict, PyTorch Tensor
    # Returns a plot
    
    
    # Convert to a PyTorch Variable and get the predictions
    cv_predictions = model(Variable(cv_predictors, requires_grad = False))
    
    # Convert that to a numpy array
    cv_predictions = cv_predictions.data.numpy()
    
    # Put it in log-transformed scale and convert it to a list
    cv_predictions = (cv_predictions*old_sd + old_mu).tolist()
    
    
    # Put the observed outcomes in log-transformed scale
    # and convert it to a list
    cv_obs = (cv_obs.numpy()*old_sd + old_mu).tolist()
    
    
    # Plot it
    plt.scatter(cv_obs, cv_predictions, facecolors = "none", edgecolors = "k")
    axes = plt.gca()
    axes.set_xlim([-1, 24])
    axes.set_ylim([-1, 24])
    axes.set_xticks([0, 3, 6, 9, 12, 15, 18, 21, 24])
    axes.set_yticks([0, 3, 6, 9, 12, 15, 18, 21, 24])
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.plot([-1, 24], [-1, 24], 'k-', lw = 2)
    axes.set_xlabel("Observed (Log-Transformed US Dollars + 1)", size = 14)
    axes.set_ylabel("Predicted (Log-Transformed US Dollars + 1)", size = 14)
    axes.set_ylabel("Predicted (Log-Transformed US Dollars + 1)")
    axes.set_title("Model Performance on Cross-Validation Data", size = 16)
    plt.text(0.5, 22, r"$R^2$ = %s"%(R_squared.item()), size = 12)
    plt.text(0.5, 20, "MSE = %s"%(MSE.item()), size = 12)
    plt.text(0.5, 18, "MSE over 1M = %s"%(MSE_over_1mil.item()), size = 12)

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# ### 1.3 Store Predictions

# %%
def convert_pred_to_df(predictors_to_use, notebook_id, model_id, dataset, true_values_to_use):
    
    # Saves the model predictions as a DataFrame, pairs these predictions with a
    #    notebook identifier, model identifier, the dataset (cv or test), and
    #    the corresponding true values (observations)
    # The following inputs are numbers: notebook_id, model_id
    # dataset = either 'cv' or 'test'
    # predictors_to_use, true_values_to_use = PyTorch Tensors
    # Returns a DataFrame
    
    
    # Convert the Tensor into a Variable and predict off of it
    model_pred = model(Variable(predictors_to_use))
    
    # Convert that Variable into a list
    model_pred = model_pred.data.numpy().tolist()
    
    # Convert that list into a DataFrame
    model_pred = pd.DataFrame(model_pred)
    
    # Give the column an appropriate name
    model_pred.columns = ["predicted_values"]
    
    
    # Add notebook identifier as a column
    model_pred["notebook_number"] = pd.Series(np.repeat(notebook_id,
                                                        len(model_pred["predicted_values"])))
    
    # Add model identifier as a column
    model_pred["model_number"] = pd.Series(np.repeat(model_id,
                                                     len(model_pred["predicted_values"])))
    
    # Add the data set as a column
    model_pred["data_set"] = pd.Series(np.repeat(dataset,
                                                 len(model_pred["predicted_values"])))
    
    # Add the observed values as a column
    model_pred["true_values"] = pd.DataFrame(true_values_to_use.numpy().tolist())
    return(model_pred)

# %%
stored_cv_pred_df = convert_pred_to_df(cv_predictors_Tensor, 17, 1, 'cv', cv_outcome_Tensor)

stored_test_pred_df = convert_pred_to_df(test_predictors_Tensor, 17, 1, 'test', test_outcome_Tensor)

# %% [markdown]
# ## 2. Ten hidden layers, 34 neurons each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(number_input, hidden_size)
        self.fc2 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc3 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc4 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc5 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc6 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc7 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc8 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc9 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc10 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc11 = torch.nn.Linear(hidden_size, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = self.fc11(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 2.1 Performance Metrics

# %%
# Compute the metrics
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = (((number_input + 1) * hidden_size) +
                        (((hidden_size + 1) * hidden_size) * 9) +
                        ((hidden_size + 1) * 1))

# Save the metrics in a temporary DataFrame
temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 17, 2)

# Append that temporary DataFrame onto the existing one
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 2.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# ### 2.3 Store Predictions

# %%
# Using temporary DataFrames to append the new predictions onto the existing predictions DataFrame
temp_df = convert_pred_to_df(cv_predictors_Tensor, 17, 2, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 17, 2, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 3. Fifteen hidden layers, 34 neurons each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(number_input, hidden_size)
        self.fc2 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc3 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc4 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc5 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc6 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc7 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc8 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc9 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc10 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc11 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc12 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc13 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc14 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc15 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc16 = torch.nn.Linear(hidden_size, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = self.fc16(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 3.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = (((number_input + 1) * hidden_size) +
                        (((hidden_size + 1) * hidden_size) * 14) +
                        ((hidden_size + 1) * 1))

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 17, 3)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 3.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# ### 3.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 17, 3, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 17, 3, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 4. Twenty hidden layers, 34 neurons each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(number_input, hidden_size)
        self.fc2 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc3 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc4 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc5 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc6 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc7 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc8 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc9 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc10 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc11 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc12 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc13 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc14 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc15 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc16 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc17 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc18 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc19 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc20 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc21 = torch.nn.Linear(hidden_size, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = self.fc21(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 4.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = (((number_input + 1) * hidden_size) +
                        (((hidden_size + 1) * hidden_size) * 19) +
                        ((hidden_size + 1) * 1))

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 17, 4)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 4.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# ### 4.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 17, 4, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 17, 4, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 5. Twenty-five hidden layers, 34 neurons each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(number_input, hidden_size)
        self.fc2 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc3 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc4 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc5 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc6 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc7 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc8 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc9 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc10 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc11 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc12 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc13 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc14 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc15 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc16 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc17 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc18 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc19 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc20 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc21 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc22 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc23 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc24 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc25 = torch.nn.Linear(hidden_size, hidden_size)
        self.fchidden_size = torch.nn.Linear(hidden_size, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = torch.nn.functional.relu(self.fc21(x))
        x = torch.nn.functional.relu(self.fc22(x))
        x = torch.nn.functional.relu(self.fc23(x))
        x = torch.nn.functional.relu(self.fc24(x))
        x = torch.nn.functional.relu(self.fc25(x))
        x = self.fchidden_size(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 5.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = (((number_input + 1) * hidden_size) +
                        (((hidden_size + 1) * hidden_size) * 24) +
                        ((hidden_size + 1) * 1))

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 17, 5)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 5.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# ### 5.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 17, 5, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 17, 5, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 6. Thirty hidden layers, 34 neurons each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(number_input, hidden_size)
        self.fc2 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc3 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc4 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc5 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc6 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc7 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc8 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc9 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc10 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc11 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc12 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc13 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc14 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc15 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc16 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc17 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc18 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc19 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc20 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc21 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc22 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc23 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc24 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc25 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc26 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc27 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc28 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc29 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc30 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc31 = torch.nn.Linear(hidden_size, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = torch.nn.functional.relu(self.fc21(x))
        x = torch.nn.functional.relu(self.fc22(x))
        x = torch.nn.functional.relu(self.fc23(x))
        x = torch.nn.functional.relu(self.fc24(x))
        x = torch.nn.functional.relu(self.fc25(x))
        x = torch.nn.functional.relu(self.fc26(x))
        x = torch.nn.functional.relu(self.fc27(x))
        x = torch.nn.functional.relu(self.fc28(x))
        x = torch.nn.functional.relu(self.fc29(x))
        x = torch.nn.functional.relu(self.fc30(x))
        x = self.fc31(x)
        return(x)

    
# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 6.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = (((number_input + 1) * hidden_size) +
                        (((hidden_size + 1) * hidden_size) * 29) +
                        ((hidden_size + 1) * 1))

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 17, 6)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 6.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# ### 6.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 17, 6, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 17, 6, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 7. Thirty-five hidden layers, 34 neurons each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(number_input, hidden_size)
        self.fc2 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc3 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc4 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc5 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc6 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc7 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc8 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc9 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc10 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc11 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc12 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc13 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc14 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc15 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc16 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc17 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc18 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc19 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc20 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc21 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc22 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc23 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc24 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc25 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc26 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc27 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc28 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc29 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc30 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc31 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc32 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc33 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc34 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc35 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc36 = torch.nn.Linear(hidden_size, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = torch.nn.functional.relu(self.fc21(x))
        x = torch.nn.functional.relu(self.fc22(x))
        x = torch.nn.functional.relu(self.fc23(x))
        x = torch.nn.functional.relu(self.fc24(x))
        x = torch.nn.functional.relu(self.fc25(x))
        x = torch.nn.functional.relu(self.fc26(x))
        x = torch.nn.functional.relu(self.fc27(x))
        x = torch.nn.functional.relu(self.fc28(x))
        x = torch.nn.functional.relu(self.fc29(x))
        x = torch.nn.functional.relu(self.fc30(x))
        x = torch.nn.functional.relu(self.fc31(x))
        x = torch.nn.functional.relu(self.fc32(x))
        x = torch.nn.functional.relu(self.fc33(x))
        x = torch.nn.functional.relu(self.fc34(x))
        x = torch.nn.functional.relu(self.fc35(x))
        x = self.fc36(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ###  7.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = (((number_input + 1) * hidden_size) +
                        (((hidden_size + 1) * hidden_size) * 34) +
                        ((hidden_size + 1) * 1))

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 17, 7)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 7.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# ### 7.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 17, 7, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 17, 7, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 8. Forty hidden layers, 34 neurons each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(number_input, hidden_size)
        self.fc2 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc3 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc4 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc5 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc6 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc7 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc8 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc9 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc10 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc11 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc12 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc13 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc14 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc15 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc16 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc17 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc18 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc19 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc20 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc21 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc22 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc23 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc24 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc25 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc26 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc27 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc28 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc29 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc30 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc31 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc32 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc33 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc34 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc35 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc36 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc37 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc38 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc39 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc40 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc41 = torch.nn.Linear(hidden_size, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = torch.nn.functional.relu(self.fc21(x))
        x = torch.nn.functional.relu(self.fc22(x))
        x = torch.nn.functional.relu(self.fc23(x))
        x = torch.nn.functional.relu(self.fc24(x))
        x = torch.nn.functional.relu(self.fc25(x))
        x = torch.nn.functional.relu(self.fc26(x))
        x = torch.nn.functional.relu(self.fc27(x))
        x = torch.nn.functional.relu(self.fc28(x))
        x = torch.nn.functional.relu(self.fc29(x))
        x = torch.nn.functional.relu(self.fc30(x))
        x = torch.nn.functional.relu(self.fc31(x))
        x = torch.nn.functional.relu(self.fc32(x))
        x = torch.nn.functional.relu(self.fc33(x))
        x = torch.nn.functional.relu(self.fc34(x))
        x = torch.nn.functional.relu(self.fc35(x))
        x = torch.nn.functional.relu(self.fc36(x))
        x = torch.nn.functional.relu(self.fc37(x))
        x = torch.nn.functional.relu(self.fc38(x))
        x = torch.nn.functional.relu(self.fc39(x))
        x = torch.nn.functional.relu(self.fc40(x))
        x = self.fc41(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 8.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = (((number_input + 1) * hidden_size) +
                        (((hidden_size + 1) * hidden_size) * 39) +
                        ((hidden_size + 1) * 1))

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 17, 8)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 8.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# ### 8.3 Store Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 17, 8, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 17, 8, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 9. Forty-five hidden layers, 34 neurons each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(number_input, hidden_size)
        self.fc2 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc3 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc4 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc5 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc6 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc7 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc8 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc9 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc10 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc11 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc12 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc13 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc14 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc15 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc16 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc17 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc18 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc19 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc20 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc21 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc22 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc23 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc24 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc25 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc26 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc27 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc28 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc29 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc30 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc31 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc32 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc33 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc34 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc35 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc36 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc37 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc38 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc39 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc40 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc41 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc42 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc43 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc44 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc45 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc46 = torch.nn.Linear(hidden_size, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = torch.nn.functional.relu(self.fc21(x))
        x = torch.nn.functional.relu(self.fc22(x))
        x = torch.nn.functional.relu(self.fc23(x))
        x = torch.nn.functional.relu(self.fc24(x))
        x = torch.nn.functional.relu(self.fc25(x))
        x = torch.nn.functional.relu(self.fc26(x))
        x = torch.nn.functional.relu(self.fc27(x))
        x = torch.nn.functional.relu(self.fc28(x))
        x = torch.nn.functional.relu(self.fc29(x))
        x = torch.nn.functional.relu(self.fc30(x))
        x = torch.nn.functional.relu(self.fc31(x))
        x = torch.nn.functional.relu(self.fc32(x))
        x = torch.nn.functional.relu(self.fc33(x))
        x = torch.nn.functional.relu(self.fc34(x))
        x = torch.nn.functional.relu(self.fc35(x))
        x = torch.nn.functional.relu(self.fc36(x))
        x = torch.nn.functional.relu(self.fc37(x))
        x = torch.nn.functional.relu(self.fc38(x))
        x = torch.nn.functional.relu(self.fc39(x))
        x = torch.nn.functional.relu(self.fc40(x))
        x = torch.nn.functional.relu(self.fc41(x))
        x = torch.nn.functional.relu(self.fc42(x))
        x = torch.nn.functional.relu(self.fc43(x))
        x = torch.nn.functional.relu(self.fc44(x))
        x = torch.nn.functional.relu(self.fc45(x))
        x = self.fc46(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 9.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = (((number_input + 1) * hidden_size) +
                        (((hidden_size + 1) * hidden_size) * 44) +
                        ((hidden_size + 1) * 1))

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 17, 9)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 9.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# ### 9.3 Save Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 17, 9, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 17, 9, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ## 10. Fifty hidden layers, 34 neurons each

# %%
# Define the neural network
class Net(torch.nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(number_input, hidden_size)
        self.fc2 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc3 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc4 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc5 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc6 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc7 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc8 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc9 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc10 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc11 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc12 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc13 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc14 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc15 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc16 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc17 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc18 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc19 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc20 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc21 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc22 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc23 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc24 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc25 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc26 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc27 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc28 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc29 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc30 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc31 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc32 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc33 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc34 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc35 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc36 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc37 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc38 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc39 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc40 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc41 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc42 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc43 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc44 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc45 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc46 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc47 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc48 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc49 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc50 = torch.nn.Linear(hidden_size, hidden_size)
        self.fc51 = torch.nn.Linear(hidden_size, 1)
        
    def forward(self, x):
        x = torch.nn.functional.relu(self.fc1(x))
        x = torch.nn.functional.relu(self.fc2(x))
        x = torch.nn.functional.relu(self.fc3(x))
        x = torch.nn.functional.relu(self.fc4(x))
        x = torch.nn.functional.relu(self.fc5(x))
        x = torch.nn.functional.relu(self.fc6(x))
        x = torch.nn.functional.relu(self.fc7(x))
        x = torch.nn.functional.relu(self.fc8(x))
        x = torch.nn.functional.relu(self.fc9(x))
        x = torch.nn.functional.relu(self.fc10(x))
        x = torch.nn.functional.relu(self.fc11(x))
        x = torch.nn.functional.relu(self.fc12(x))
        x = torch.nn.functional.relu(self.fc13(x))
        x = torch.nn.functional.relu(self.fc14(x))
        x = torch.nn.functional.relu(self.fc15(x))
        x = torch.nn.functional.relu(self.fc16(x))
        x = torch.nn.functional.relu(self.fc17(x))
        x = torch.nn.functional.relu(self.fc18(x))
        x = torch.nn.functional.relu(self.fc19(x))
        x = torch.nn.functional.relu(self.fc20(x))
        x = torch.nn.functional.relu(self.fc21(x))
        x = torch.nn.functional.relu(self.fc22(x))
        x = torch.nn.functional.relu(self.fc23(x))
        x = torch.nn.functional.relu(self.fc24(x))
        x = torch.nn.functional.relu(self.fc25(x))
        x = torch.nn.functional.relu(self.fc26(x))
        x = torch.nn.functional.relu(self.fc27(x))
        x = torch.nn.functional.relu(self.fc28(x))
        x = torch.nn.functional.relu(self.fc29(x))
        x = torch.nn.functional.relu(self.fc30(x))
        x = torch.nn.functional.relu(self.fc31(x))
        x = torch.nn.functional.relu(self.fc32(x))
        x = torch.nn.functional.relu(self.fc33(x))
        x = torch.nn.functional.relu(self.fc34(x))
        x = torch.nn.functional.relu(self.fc35(x))
        x = torch.nn.functional.relu(self.fc36(x))
        x = torch.nn.functional.relu(self.fc37(x))
        x = torch.nn.functional.relu(self.fc38(x))
        x = torch.nn.functional.relu(self.fc39(x))
        x = torch.nn.functional.relu(self.fc40(x))
        x = torch.nn.functional.relu(self.fc41(x))
        x = torch.nn.functional.relu(self.fc42(x))
        x = torch.nn.functional.relu(self.fc43(x))
        x = torch.nn.functional.relu(self.fc44(x))
        x = torch.nn.functional.relu(self.fc45(x))
        x = torch.nn.functional.relu(self.fc46(x))
        x = torch.nn.functional.relu(self.fc47(x))
        x = torch.nn.functional.relu(self.fc48(x))
        x = torch.nn.functional.relu(self.fc49(x))
        x = torch.nn.functional.relu(self.fc50(x))
        x = self.fc51(x)
        return(x)


# Make it
model = Net()

# %%
train_neural_net(model, outcome_Tensor, predictors_Tensor,
                 cv_outcome_Tensor, cv_predictors_Tensor)

# %%
plot_train_perf(predictors_Tensor, outcome_Tensor)

# %% [markdown]
# ### 10.1 Performance Metrics

# %%
MSE = compute_MSE(cv_predictors_Tensor, cv_outcome_Tensor)

MSE_over_1mil = compute_MSE_over_1mil(cv_predictors_Tensor, cv_outcome_Tensor)

R_squared = compute_R_squared(cv_predictors_Tensor, cv_outcome_Tensor)

Number_of_Parameters = (((number_input + 1) * hidden_size) +
                        (((hidden_size + 1) * hidden_size) * 49) +
                        ((hidden_size + 1) * 1))

temp_df = save_metrics(Number_of_Parameters, R_squared, MSE, MSE_over_1mil, 17, 10)
metrics_df = metrics_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### 10.2 Performance Visualization

# %%
plot_cross_valid_perf(cv_predictors_Tensor, cv_outcome_Tensor)

# %% [markdown]
# ## 10.3 Save Predictions

# %%
temp_df = convert_pred_to_df(cv_predictors_Tensor, 17, 10, 'cv', cv_outcome_Tensor)
stored_cv_pred_df = stored_cv_pred_df.append(temp_df, ignore_index = True)

temp_df = convert_pred_to_df(test_predictors_Tensor, 17, 10, 'test', test_outcome_Tensor)
stored_test_pred_df = stored_test_pred_df.append(temp_df, ignore_index = True)

# %% [markdown]
# ### Take a look at what we're saving

# %%
stored_cv_pred_df.head()
# Out:
#    predicted_values  notebook_number  model_number data_set  true_values
# 0          0.520252               17             1       cv     0.152815
# 1          0.454325               17             1       cv     0.865890
# 2          0.557521               17             1       cv     1.017562
# 3          0.704445               17             1       cv     0.837310
# 4          0.981872               17             1       cv     0.891966

# %%
stored_test_pred_df.head()
# Out:
#    predicted_values  notebook_number  model_number data_set  true_values
# 0          0.147578               17             1     test     0.751832
# 1          0.477165               17             1     test     0.294756
# 2          0.499112               17             1     test     0.281566
# 3          0.727914               17             1     test     0.573976
# 4          0.716187               17             1     test     1.430518

# %%
metrics_df
# Out:
#    Number of Parameters  R-squared  Mean Squared Error  \
# 0                  7141   0.376656            0.106387
# 1                 13091   0.396650            0.102975
# 2                 19041   0.405059            0.101540
# 3                 24991   0.416269            0.099626
# 4                 30941   0.395993            0.103087
# 5                 36891   0.435735            0.096304
# 6                 42841   0.404248            0.101678
# 7                 48791  -0.000079            0.170685
# 8                 54741  -0.000906            0.170826
# 9                 60691  -0.000040            0.170678
#
#    Mean Squared Error Over 1M  notebook_id  model_id
# 0                    0.216169           17         1
# 1                    0.217084           17         2
# 2                    0.218976           17         3
# 3                    0.221152           17         4
# 4                    0.212075           17         5
# 5                    0.212865           17         6
# 6                    0.224974           17         7
# 7                    0.628664           17         8
# 8                    0.641872           17         9
# 9                    0.627040           17        10

# %%
# Save the stored predictions and outcomes as a .csv
stored_cv_pred_df.to_csv("17_cv_perf.csv")

stored_test_pred_df.to_csv("17_test_perf.csv")

metrics_df.to_csv("17_metrics.csv")
